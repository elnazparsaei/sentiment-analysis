# %%
import os
from nltk.corpus import stopwords
from nltk import word_tokenize
from string import punctuation
import random

# %%
os.listdir('data/neg')
# Out:
# ['.ipynb_checkpoints',
#  'cv000_29416.txt',
#  'cv001_19502.txt',
#  'cv002_17424.txt',
#  'cv003_12683.txt',
#  'cv004_12641.txt',
#  'cv005_29357.txt',
#  'cv006_17022.txt',
#  'cv007_4992.txt',
#  'cv008_29326.txt',
#  'cv009_29417.txt',
#  'cv010_29063.txt',
#  'cv011_13044.txt',
#  'cv012_29411.txt',
#  'cv013_10494.txt',
#  'cv014_15600.txt',
#  'cv015_29356.txt',
#  'cv016_4348.txt',
#  'cv017_23487.txt',
#  'cv018_21672.txt',
#  'cv019_16117.txt',
#  'cv020_9234.txt',
#  'cv021_17313.txt',
#  'cv022_14227.txt',
#  'cv023_13847.txt',
#  'cv024_7033.txt',
#  'cv025_29825.txt',
#  'cv026_29229.txt',
#  'cv027_26270.txt',
#  'cv028_26964.txt',
#  'cv029_19943.txt',
#  'cv030_22893.txt',
#  'cv031_19540.txt',
#  'cv032_23718.txt',
#  'cv033_25680.txt',
#  'cv034_29446.txt',
#  'cv035_3343.txt',
#  'cv036_18385.txt',
#  'cv037_19798.txt',
#  'cv038_9781.txt',
#  'cv039_5963.txt',
#  'cv040_8829.txt',
#  'cv041_22364.txt',
#  'cv042_11927.txt',
#  'cv043_16808.txt',
#  'cv044_18429.txt',
#  'cv045_25077.txt',
#  'cv046_10613.txt',
#  'cv047_18725.txt',
#  'cv048_18380.txt',
#  'cv049_21917.txt',
#  'cv050_12128.txt',
#  'cv051_10751.txt',
#  'cv052_29318.txt',
#  'cv053_23117.txt',
#  'cv054_4101.txt',
#  'cv055_8926.txt',
#  'cv056_14663.txt',
#  'cv057_7962.txt',
#  'cv058_8469.txt',
#  'cv059_28723.txt',
#  'cv060_11754.txt',
#  'cv061_9321.txt',
#  'cv062_24556.txt',
#  'cv063_28852.txt',
#  'cv064_25842.txt',
#  'cv065_16909.txt',
#  'cv066_11668.txt',
#  'cv067_21192.txt',
#  'cv068_14810.txt',
#  'cv069_11613.txt',
#  'cv070_13249.txt',
#  'cv071_12969.txt',
#  'cv072_5928.txt',
#  'cv073_23039.txt',
#  'cv074_7188.txt',
#  'cv075_6250.txt',
#  'cv076_26009.txt',
#  'cv077_23172.txt',
#  'cv078_16506.txt',
#  'cv079_12766.txt',
#  'cv080_14899.txt',
#  'cv081_18241.txt',
#  'cv082_11979.txt',
#  'cv083_25491.txt',
#  'cv084_15183.txt',
#  'cv085_15286.txt',
#  'cv086_19488.txt',
#  'cv087_2145.txt',
#  'cv088_25274.txt',
#  'cv089_12222.txt',
#  'cv090_0049.txt',
#  'cv091_7899.txt',
#  'cv092_27987.txt',
#  'cv093_15606.txt',
#  'cv094_27868.txt',
#  'cv095_28730.txt',
#  'cv096_12262.txt',
#  'cv097_26081.txt',
#  'cv098_17021.txt',
#  'cv099_11189.txt',
#  'cv100_12406.txt',
#  'cv101_10537.txt',
#  'cv102_8306.txt',
#  'cv103_11943.txt',
#  'cv104_19176.txt',
#  'cv217_28707.txt',
#  'cv218_25651.txt',
#  'cv219_19874.txt',
#  'cv220_28906.txt',
#  'cv221_27081.txt',
#  'cv222_18720.txt',
#  'cv223_28923.txt',
#  'cv224_18875.txt',
#  'cv225_29083.txt',
#  'cv226_26692.txt',
#  'cv227_25406.txt',
#  'cv228_5644.txt',
#  'cv229_15200.txt',
#  'cv230_7913.txt',
#  'cv231_11028.txt',
#  'cv232_16768.txt',
#  'cv233_17614.txt',
#  'cv234_22123.txt',
#  'cv235_10704.txt',
#  'cv236_12427.txt',
#  'cv237_20635.txt',
#  'cv238_14285.txt',
#  'cv239_29828.txt',
#  'cv240_15948.txt',
#  'cv241_24602.txt',
#  'cv242_11354.txt',
#  'cv243_22164.txt',
#  'cv244_22935.txt',
#  'cv245_8938.txt',
#  'cv246_28668.txt',
#  'cv247_14668.txt',
#  'cv248_15672.txt',
#  'cv249_12674.txt',
#  'cv250_26462.txt',
#  'cv251_23901.txt',
#  'cv252_24974.txt',
#  'cv253_10190.txt',
#  'cv254_5870.txt',
#  'cv255_15267.txt',
#  'cv256_16529.txt',
#  'cv257_11856.txt',
#  'cv258_5627.txt',
#  'cv259_11827.txt',
#  'cv260_15652.txt',
#  'cv261_11855.txt',
#  'cv262_13812.txt',
#  'cv263_20693.txt',
#  'cv264_14108.txt',
#  'cv265_11625.txt',
#  'cv266_26644.txt',
#  'cv267_16618.txt',
#  'cv268_20288.txt',
#  'cv269_23018.txt',
#  'cv270_5873.txt',
#  'cv271_15364.txt',
#  'cv272_20313.txt',
#  'cv273_28961.txt',
#  'cv274_26379.txt',
#  'cv275_28725.txt',
#  'cv276_17126.txt',
#  'cv277_20467.txt',
#  'cv278_14533.txt',
#  'cv279_19452.txt',
#  'cv280_8651.txt',
#  'cv281_24711.txt',
#  'cv282_6833.txt',
#  'cv283_11963.txt',
#  'cv284_20530.txt',
#  'cv285_18186.txt',
#  'cv286_26156.txt',
#  'cv287_17410.txt',
#  'cv288_20212.txt',
#  'cv289_6239.txt',
#  'cv290_11981.txt',
#  'cv291_26844.txt',
#  'cv292_7804.txt',
#  'cv293_29731.txt',
#  'cv294_12695.txt',
#  'cv295_17060.txt',
#  'cv296_13146.txt',
#  'cv297_10104.txt',
#  'cv298_24487.txt',
#  'cv299_17950.txt',
#  'cv300_23302.txt',
#  'cv301_13010.txt',
#  'cv302_26481.txt',
#  'cv303_27366.txt',
#  'cv304_28489.txt',
#  'cv305_9937.txt',
#  'cv306_10859.txt',
#  'cv307_26382.txt',
#  'cv308_5079.txt',
#  'cv309_23737.txt',
#  'cv310_14568.txt',
#  'cv311_17708.txt',
#  'cv312_29308.txt',
#  'cv313_19337.txt',
#  'cv314_16095.txt',
#  'cv315_12638.txt',
#  'cv316_5972.txt',
#  'cv317_25111.txt',
#  'cv318_11146.txt',
#  'cv319_16459.txt',
#  'cv320_9693.txt',
#  'cv321_14191.txt',
#  'cv322_21820.txt',
#  'cv323_29633.txt',
#  'cv324_7502.txt',
#  'cv325_18330.txt',
#  'cv326_14777.txt',
#  'cv327_21743.txt',
#  'cv884_15230.txt',
#  'cv885_13390.txt',
#  'cv886_19210.txt',
#  'cv887_5306.txt',
#  'cv888_25678.txt',
#  'cv889_22670.txt',
#  'cv890_3515.txt',
#  'cv891_6035.txt',
#  'cv892_18788.txt',
#  'cv893_26731.txt',
#  'cv894_22140.txt',
#  'cv895_22200.txt',
#  'cv896_17819.txt',
#  'cv897_11703.txt',
#  'cv898_1576.txt',
#  'cv899_17812.txt',
#  'cv900_10800.txt',
#  'cv901_11934.txt',
#  'cv902_13217.txt',
#  'cv903_18981.txt',
#  'cv904_25663.txt',
#  'cv905_28965.txt',
#  'cv906_12332.txt',
#  'cv907_3193.txt',
#  'cv908_17779.txt',
#  'cv909_9973.txt',
#  'cv910_21930.txt',
#  'cv911_21695.txt',
#  'cv912_5562.txt',
#  'cv913_29127.txt',
#  'cv914_2856.txt',
#  'cv915_9342.txt',
#  'cv916_17034.txt',
#  'cv917_29484.txt',
#  'cv918_27080.txt',
#  'cv919_18155.txt',
#  'cv920_29423.txt',
#  'cv921_13988.txt',
#  'cv922_10185.txt',
#  'cv923_11951.txt',
#  'cv924_29397.txt',
#  'cv925_9459.txt',
#  'cv926_18471.txt',
#  'cv927_11471.txt',
#  'cv928_9478.txt',
#  'cv929_1841.txt',
#  'cv930_14949.txt',
#  'cv931_18783.txt',
#  'cv932_14854.txt',
#  'cv933_24953.txt',
#  'cv934_20426.txt',
#  'cv935_24977.txt',
#  'cv936_17473.txt',
#  'cv937_9816.txt',
#  'cv938_10706.txt',
#  'cv939_11247.txt',
#  'cv940_18935.txt',
#  'cv941_10718.txt',
#  'cv942_18509.txt',
#  'cv943_23547.txt',
#  'cv944_15042.txt',
#  'cv945_13012.txt',
#  'cv946_20084.txt',
#  'cv947_11316.txt',
#  'cv948_25870.txt',
#  'cv949_21565.txt',
#  'cv950_13478.txt',
#  'cv951_11816.txt',
#  'cv952_26375.txt',
#  'cv953_7078.txt',
#  'cv954_19932.txt',
#  'cv955_26154.txt',
#  'cv956_12547.txt',
#  'cv957_9059.txt',
#  'cv958_13020.txt',
#  'cv959_16218.txt',
#  'cv960_28877.txt',
#  'cv961_5578.txt',
#  'cv962_9813.txt',
#  'cv963_7208.txt',
#  'cv964_5794.txt',
#  'cv965_26688.txt',
#  'cv966_28671.txt',
#  'cv967_5626.txt',
#  'cv968_25413.txt',
#  'cv969_14760.txt',
#  'cv970_19532.txt',
#  'cv971_11790.txt',
#  'cv972_26837.txt',
#  'cv973_10171.txt',
#  'cv974_24303.txt',
#  'cv975_11920.txt',
#  'cv976_10724.txt',
#  'cv977_4776.txt',
#  'cv978_22192.txt',
#  'cv979_2029.txt',
#  'cv980_11851.txt',
#  'cv981_16679.txt',
#  'cv982_22209.txt',
#  'cv983_24219.txt',
#  'cv984_14006.txt',
#  'cv985_5964.txt',
#  'cv986_15092.txt',
#  'cv987_7394.txt',
#  'cv988_20168.txt',
#  'cv989_17297.txt',
#  'cv990_12443.txt',
#  'cv991_19973.txt',
#  'cv992_12806.txt',
#  'cv993_29565.txt',
#  'cv994_13229.txt',
#  'cv995_23113.txt',
#  'cv996_12447.txt',
#  'cv997_5152.txt',
#  'cv998_15691.txt',
#  ...]

# %%
s = str.maketrans('', '', punctuation)#tranlator
a = 'salam!@'
a.translate(s)
# Out:
# 'salam'

# %%
stop_words = stopwords.words('english')

# %%
negative_documents = []
max_len_negative = 0
for file in os.listdir('data/neg'):
    if not file.endswith('ipynb_checkpoints'):
        with open('data/neg/' + file) as f:
            text = f.read()
            tokens = word_tokenize(text)
            translator = str.maketrans('', '', punctuation)
            tokens = [w.translate(translator) for w in tokens]
            tokens = [w for w in tokens if not w in stop_words]
            if len(tokens) > max_len_negative:
                max_len_negative = len(tokens)
            negative_documents.append(' '.join(tokens))
len(negative_documents)
# Out:
# 1000

# %%
max_len_negative
# Out:
# 1400

# %%
positive_documents = []
max_len_positive = 0
for file in os.listdir('data/pos'):
    with open('data/pos/' + file) as f:
        text = f.read()
        tokens = word_tokenize(text)
        translator = str.maketrans('', '', punctuation)
        tokens = [w.translate(translator) for w in tokens]
        tokens = [w for w in tokens if not w in stop_words]
        if len(tokens) > max_len_positive:
            max_len_positive = len(tokens)
        positive_documents.append(' '.join(tokens))
len(positive_documents)
# Out:
# 1000

# %%
max_len_positive
# Out:
# 1693

# %%
max_len = max(max_len_negative, max_len_positive)

# %%
random.shuffle(negative_documents)
random.shuffle(positive_documents)

# %%
X_train = negative_documents[:800] + positive_documents[:800]

# %%
len(X_train)
# Out:
# 1600

# %%
y_train = [0 for _ in range(800)] + [1 for _ in range(800)]

# %%
len(y_train)
# Out:
# 1600

# %%
X_test = negative_documents[800:] + positive_documents[800:]
len(X_test)
# Out:
# 400

# %%
y_test = [0 for _ in range(200)] + [1 for _ in range(200)]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten, Embedding, Conv1D, MaxPool1D, Dropout
from tensorflow.keras.layers import concatenate

# %%
max_len
# Out:
# 1693

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
import pickle
with open('tokenizer.h5', 'wb') as f:
    pickle.dump(tokenizer, f)

# %%
tokenizer

# %%
vocab_len = len(tokenizer.word_index) + 1

# %%
vocab_len
# Out:
# 40423

# %%
encoded = tokenizer.texts_to_sequences(X_train)

# %%
encoded[0]
# Out:
# [4,
#  23923,
#  8506,
#  1,
#  2569,
#  2639,
#  1,
#  213,
#  2287,
#  5243,
#  2945,
#  2139,
#  1179,
#  1162,
#  6480,
#  1552,
#  312,
#  41,
#  253,
#  1552,
#  47,
#  1356,
#  71,
#  23924,
#  5244,
#  1552,
#  10181,
#  454,
#  3,
#  15061,
#  8507,
#  42,
#  4988,
#  2505,
#  1311,
#  1552,
#  4381,
#  2570,
#  8508,
#  14,
#  1694,
#  2140,
#  4382,
#  10182,
#  441,
#  69,
#  23925,
#  15062,
#  6125,
#  429,
#  408,
#  1289,
#  1,
#  415,
#  11374,
#  11375,
#  8509,
#  3,
#  1584,
#  819,
#  10183,
#  84,
#  6126,
#  12939,
#  782,
#  7363,
#  208,
#  1885,
#  5243,
#  12940,
#  12941,
#  317,
#  156,
#  11376,
#  842,
#  1275,
#  10183,
#  9258,
#  587,
#  56,
#  1002,
#  1255,
#  523,
#  23926,
#  257,
#  4,
#  5527,
#  5243,
#  341,
#  326,
#  819,
#  415,
#  109,
#  69,
#  658,
#  10184,
#  355,
#  19,
#  4773,
#  5243,
#  1082,
#  2772,
#  10183,
#  2640,
#  11377,
#  14,
#  10183,
#  23927,
#  3031,
#  355,
#  3032,
#  4774,
#  48,
#  134,
#  676,
#  10183,
#  109,
#  2447,
#  989,
#  990,
#  12940,
#  12941,
#  6898,
#  18270,
#  2641,
#  5244,
#  212,
#  1478,
#  524,
#  391,
#  230,
#  2505,
#  15,
#  8510,
#  2700,
#  1,
#  1695,
#  1552,
#  2,
#  170,
#  115,
#  889,
#  269,
#  40,
#  782,
#  177,
#  272,
#  123,
#  1083,
#  704,
#  293,
#  1,
#  2642,
#  828,
#  613,
#  15,
#  317,
#  429,
#  49,
#  113,
#  9259,
#  1,
#  49,
#  195,
#  2844,
#  316,
#  607,
#  1235,
#  297,
#  4567,
#  1162,
#  1552,
#  482,
#  1180,
#  1210,
#  1023,
#  151,
#  1988,
#  345,
#  36,
#  297,
#  2240,
#  5804,
#  18271,
#  6,
#  18272,
#  3033,
#  6481,
#  4568,
#  104,
#  2,
#  7,
#  233,
#  6126,
#  12939,
#  2339,
#  4775,
#  1822,
#  4569,
#  30,
#  104,
#  33,
#  233,
#  91,
#  3325,
#  2571,
#  1612,
#  5528,
#  2,
#  1669,
#  618,
#  2506,
#  63,
#  69,
#  579,
#  991,
#  3626,
#  2096,
#  796,
#  1908,
#  5243,
#  1256,
#  12940,
#  12941,
#  8511,
#  1,
#  440,
#  195,
#  6,
#  1989,
#  770,
#  108,
#  22,
#  2,
#  154,
#  1,
#  346,
#  291,
#  922,
#  114,
#  242,
#  47,
#  7880,
#  2845,
#  7881,
#  9260,
#  534,
#  3,
#  4383,
#  15,
#  90,
#  44,
#  103,
#  803,
#  35,
#  2096,
#  1851,
#  705,
#  1,
#  648,
#  1333,
#  2846,
#  4,
#  1851,
#  1119,
#  12,
#  10183,
#  1909,
#  543,
#  84,
#  7882,
#  9261,
#  1276,
#  49,
#  81,
#  3894,
#  2141,
#  719,
#  4384,
#  5245,
#  214,
#  1,
#  8,
#  187,
#  4776,
#  2287,
#  5243,
#  18273,
#  23928,
#  771,
#  3,
#  2639,
#  74,
#  4,
#  12942,
#  3410,
#  2570,
#  8508,
#  377]

# %%
padded = pad_sequences(encoded, maxlen=max_len, padding='post')

# %%
padded.shape
# Out:
# (1600, 1693)

# %%
input1 = Input(shape=(max_len,))
embedding1 = Embedding(vocab_len, 100)(input1)
conv1 = Conv1D(filters=32, kernel_size=4, activation='relu')(embedding1)
drop1 = Dropout(0.5)(conv1)
pool1 = MaxPool1D(pool_size=2)(drop1)
flat1 = Flatten()(pool1)
dense1 = Dense(10, activation='relu')(flat1)
output = Dense(1, activation='sigmoid')(dense1)

# %%
model = Model(inputs=[input1], outputs=output)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1693)]            0
#
#  embedding (Embedding)       (None, 1693, 100)         4042300
#
#  conv1d (Conv1D)             (None, 1690, 32)          12832
#
#  dropout (Dropout)           (None, 1690, 32)          0
#
#  max_pooling1d (MaxPooling1D  (None, 845, 32)          0
#  )
#
#  flatten (Flatten)           (None, 27040)             0
#
#  dense (Dense)               (None, 10)                270410
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 4,325,553
# Trainable params: 4,325,553
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True)

# %%
encoded_test = tokenizer.texts_to_sequences(X_test)
padded_test = pad_sequences(encoded_test, maxlen=max_len, padding='post')

# %%
padded_test.shape
# Out:
# (400, 1693)

# %%
import numpy as np

# %%
model.fit([padded], np.array(y_train), epochs=10, batch_size=20, validation_data=([padded_test], np.array(y_test)))
# Out:
# Epoch 1/10
# 80/80 [==============================] - 8s 92ms/step - loss: 0.6943 - accuracy: 0.4994 - val_loss: 0.6910 - val_accuracy: 0.5625
# Epoch 2/10
# 80/80 [==============================] - 7s 91ms/step - loss: 0.6727 - accuracy: 0.5594 - val_loss: 0.6751 - val_accuracy: 0.5375
# Epoch 3/10
# 80/80 [==============================] - 8s 100ms/step - loss: 0.5258 - accuracy: 0.7775 - val_loss: 0.5693 - val_accuracy: 0.7275
# Epoch 4/10
# 80/80 [==============================] - 8s 95ms/step - loss: 0.1562 - accuracy: 0.9581 - val_loss: 0.5062 - val_accuracy: 0.7775
# Epoch 5/10
# 80/80 [==============================] - 8s 97ms/step - loss: 0.0177 - accuracy: 0.9956 - val_loss: 0.4613 - val_accuracy: 0.8225
# Epoch 6/10
# 80/80 [==============================] - 8s 105ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.5005 - val_accuracy: 0.8150
# Epoch 7/10
# 80/80 [==============================] - 8s 102ms/step - loss: 5.6098e-04 - accuracy: 1.0000 - val_loss: 0.5012 - val_accuracy: 0.8075
# Epoch 8/10
# 80/80 [==============================] - 8s 94ms/step - loss: 3.1294e-04 - accuracy: 1.0000 - val_loss: 0.5221 - val_accuracy: 0.8075
# Epoch 9/10
# 80/80 [==============================] - 8s 96ms/step - loss: 2.3326e-04 - accuracy: 1.0000 - val_loss: 0.5337 - val_accuracy: 0.8050
# Epoch 10/10
# 80/80 [==============================] - 8s 99ms/step - loss: 1.6953e-04 - accuracy: 1.0000 - val_loss: 0.5406 - val_accuracy: 0.8050

# %%
model.save('textcnn.h5')

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('textcnn.h5')

# %%
with open('tokenizer.h5', 'rb') as f:
    tokenizer = pickle.load(f)

# %%
tokenizer.word_index
# Out:
# {'film': 1,
#  'nt': 2,
#  'movie': 3,
#  'one': 4,
#  'like': 5,
#  'even': 6,
#  'good': 7,
#  'would': 8,
#  'time': 9,
#  'story': 10,
#  'much': 11,
#  'character': 12,
#  'get': 13,
#  'also': 14,
#  'characters': 15,
#  'two': 16,
#  'first': 17,
#  'see': 18,
#  'way': 19,
#  'well': 20,
#  'make': 21,
#  'could': 22,
#  'life': 23,
#  'really': 24,
#  'films': 25,
#  'little': 26,
#  'people': 27,
#  'plot': 28,
#  'scene': 29,
#  'man': 30,
#  'bad': 31,
#  'never': 32,
#  'best': 33,
#  'new': 34,
#  'many': 35,
#  'scenes': 36,
#  'know': 37,
#  'movies': 38,
#  'love': 39,
#  'director': 40,
#  'great': 41,
#  'another': 42,
#  'us': 43,
#  'go': 44,
#  'action': 45,
#  'seems': 46,
#  'made': 47,
#  'still': 48,
#  'end': 49,
#  'work': 50,
#  'something': 51,
#  'back': 52,
#  'makes': 53,
#  'world': 54,
#  'however': 55,
#  'every': 56,
#  'though': 57,
#  'big': 58,
#  'around': 59,
#  'audience': 60,
#  'seen': 61,
#  'enough': 62,
#  'better': 63,
#  'performance': 64,
#  'take': 65,
#  'going': 66,
#  'gets': 67,
#  'real': 68,
#  'role': 69,
#  'may': 70,
#  'years': 71,
#  'think': 72,
#  'actually': 73,
#  'nothing': 74,
#  'last': 75,
#  'things': 76,
#  'look': 77,
#  'say': 78,
#  'funny': 79,
#  'thing': 80,
#  'although': 81,
#  'comedy': 82,
#  'almost': 83,
#  'played': 84,
#  'since': 85,
#  'john': 86,
#  'find': 87,
#  'fact': 88,
#  'cast': 89,
#  'come': 90,
#  'plays': 91,
#  'script': 92,
#  'right': 93,
#  'old': 94,
#  'young': 95,
#  'ever': 96,
#  'comes': 97,
#  'long': 98,
#  'part': 99,
#  'show': 100,
#  'year': 101,
#  'star': 102,
#  'without': 103,
#  'actors': 104,
#  'family': 105,
#  'lot': 106,
#  'point': 107,
#  'acting': 108,
#  'takes': 109,
#  'original': 110,
#  'ca': 111,
#  'guy': 112,
#  'quite': 113,
#  'least': 114,
#  'anything': 115,
#  'goes': 116,
#  'minutes': 117,
#  'might': 118,
#  'course': 119,
#  'screen': 120,
#  'away': 121,
#  'interesting': 122,
#  'rather': 123,
#  'effects': 124,
#  'day': 125,
#  'three': 126,
#  'place': 127,
#  'far': 128,
#  'yet': 129,
#  'must': 130,
#  'watch': 131,
#  'fun': 132,
#  'give': 133,
#  'trying': 134,
#  'wife': 135,
#  'instead': 136,
#  'always': 137,
#  'hollywood': 138,
#  'bit': 139,
#  'times': 140,
#  'seem': 141,
#  'want': 142,
#  'picture': 143,
#  'job': 144,
#  'making': 145,
#  'home': 146,
#  'special': 147,
#  'set': 148,
#  'kind': 149,
#  'men': 150,
#  'becomes': 151,
#  'actor': 152,
#  'along': 153,
#  'help': 154,
#  'sense': 155,
#  'woman': 156,
#  'sure': 157,
#  'everything': 158,
#  'gives': 159,
#  'hard': 160,
#  'probably': 161,
#  'american': 162,
#  'become': 163,
#  'together': 164,
#  'dialogue': 165,
#  'whole': 166,
#  'wants': 167,
#  'watching': 168,
#  'given': 169,
#  'got': 170,
#  'black': 171,
#  'series': 172,
#  'money': 173,
#  'everyone': 174,
#  'high': 175,
#  'death': 176,
#  'father': 177,
#  'music': 178,
#  'pretty': 179,
#  'next': 180,
#  'sex': 181,
#  'perhaps': 182,
#  'especially': 183,
#  'done': 184,
#  'evil': 185,
#  'completely': 186,
#  'feel': 187,
#  'moments': 188,
#  'less': 189,
#  'performances': 190,
#  'play': 191,
#  'looking': 192,
#  'couple': 193,
#  'james': 194,
#  'looks': 195,
#  'several': 196,
#  'mother': 197,
#  'michael': 198,
#  'simply': 199,
#  'reason': 200,
#  'girl': 201,
#  'put': 202,
#  'rest': 203,
#  'whose': 204,
#  'friend': 205,
#  'anyone': 206,
#  'shows': 207,
#  'getting': 208,
#  'human': 209,
#  'different': 210,
#  'ending': 211,
#  'small': 212,
#  'case': 213,
#  'entire': 214,
#  'mind': 215,
#  'humor': 216,
#  '2': 217,
#  'let': 218,
#  'night': 219,
#  'found': 220,
#  'left': 221,
#  'begins': 222,
#  'horror': 223,
#  'line': 224,
#  'city': 225,
#  'soon': 226,
#  'town': 227,
#  'stars': 228,
#  'else': 229,
#  'use': 230,
#  'half': 231,
#  'unfortunately': 232,
#  'either': 233,
#  'main': 234,
#  'thought': 235,
#  'problem': 236,
#  'turns': 237,
#  'lost': 238,
#  'sequence': 239,
#  'tv': 240,
#  'house': 241,
#  'someone': 242,
#  'idea': 243,
#  'later': 244,
#  'friends': 245,
#  'believe': 246,
#  'true': 247,
#  'tries': 248,
#  'school': 249,
#  'final': 250,
#  'group': 251,
#  'name': 252,
#  'david': 253,
#  'keep': 254,
#  'based': 255,
#  'certainly': 256,
#  'relationship': 257,
#  'comic': 258,
#  'written': 259,
#  'person': 260,
#  'playing': 261,
#  'war': 262,
#  'second': 263,
#  'head': 264,
#  'boy': 265,
#  'turn': 266,
#  'said': 267,
#  'wrong': 268,
#  'works': 269,
#  'dead': 270,
#  'called': 271,
#  'despite': 272,
#  'kids': 273,
#  'tell': 274,
#  'lives': 275,
#  'book': 276,
#  'named': 277,
#  'maybe': 278,
#  'seeing': 279,
#  'camera': 280,
#  'finally': 281,
#  'children': 282,
#  'joe': 283,
#  'including': 284,
#  'used': 285,
#  'son': 286,
#  'often': 287,
#  'days': 288,
#  'perfect': 289,
#  'past': 290,
#  'hand': 291,
#  'behind': 292,
#  'style': 293,
#  'finds': 294,
#  'mr': 295,
#  'nice': 296,
#  'supposed': 297,
#  'run': 298,
#  'live': 299,
#  'shot': 300,
#  'kevin': 301,
#  'need': 302,
#  'starts': 303,
#  'alien': 304,
#  'directed': 305,
#  'able': 306,
#  'fight': 307,
#  'care': 308,
#  'lines': 309,
#  'moment': 310,
#  'side': 311,
#  'daughter': 312,
#  'worst': 313,
#  'matter': 314,
#  'hour': 315,
#  'dark': 316,
#  'beautiful': 317,
#  'full': 318,
#  'face': 319,
#  'upon': 320,
#  'worth': 321,
#  'jack': 322,
#  'game': 323,
#  'nearly': 324,
#  'others': 325,
#  'car': 326,
#  'summer': 327,
#  'throughout': 328,
#  'start': 329,
#  'violence': 330,
#  'video': 331,
#  'early': 332,
#  'example': 333,
#  'production': 334,
#  'robert': 335,
#  'try': 336,
#  'sequences': 337,
#  'simple': 338,
#  'title': 339,
#  'opening': 340,
#  'hit': 341,
#  'short': 342,
#  'already': 343,
#  'entertaining': 344,
#  'obvious': 345,
#  'screenplay': 346,
#  'team': 347,
#  'killer': 348,
#  'running': 349,
#  'drama': 350,
#  'jackie': 351,
#  'direction': 352,
#  'fine': 353,
#  'kill': 354,
#  'order': 355,
#  'exactly': 356,
#  'york': 357,
#  'version': 358,
#  'eyes': 359,
#  'roles': 360,
#  'problems': 361,
#  'tom': 362,
#  'women': 363,
#  'top': 364,
#  'knows': 365,
#  'review': 366,
#  'white': 367,
#  'major': 368,
#  'sort': 369,
#  'sometimes': 370,
#  'brother': 371,
#  'save': 372,
#  'classic': 373,
#  'supporting': 374,
#  'question': 375,
#  'jokes': 376,
#  'career': 377,
#  'lee': 378,
#  'boring': 379,
#  'earth': 380,
#  'says': 381,
#  'deep': 382,
#  'dog': 383,
#  'coming': 384,
#  'wo': 385,
#  'peter': 386,
#  'truly': 387,
#  'ship': 388,
#  'body': 389,
#  'tells': 390,
#  'heart': 391,
#  'hope': 392,
#  'room': 393,
#  'act': 394,
#  'king': 395,
#  'level': 396,
#  'yes': 397,
#  'four': 398,
#  'disney': 399,
#  'beginning': 400,
#  'child': 401,
#  'guys': 402,
#  'possible': 403,
#  'ends': 404,
#  'saw': 405,
#  'stupid': 406,
#  'attention': 407,
#  'extremely': 408,
#  'particularly': 409,
#  'known': 410,
#  'attempt': 411,
#  'dr': 412,
#  'police': 413,
#  'husband': 414,
#  'quickly': 415,
#  'worse': 416,
#  'happens': 417,
#  'genre': 418,
#  'hero': 419,
#  'close': 420,
#  'manages': 421,
#  'material': 422,
#  'fall': 423,
#  'bring': 424,
#  'taking': 425,
#  'wonder': 426,
#  'space': 427,
#  'strong': 428,
#  'result': 429,
#  'living': 430,
#  'appears': 431,
#  'eventually': 432,
#  'sound': 433,
#  'meet': 434,
#  'stop': 435,
#  'novel': 436,
#  'falls': 437,
#  'future': 438,
#  'battle': 439,
#  'mostly': 440,
#  'lead': 441,
#  'feeling': 442,
#  'sets': 443,
#  'fiction': 444,
#  'theater': 445,
#  'experience': 446,
#  'thriller': 447,
#  'hours': 448,
#  'god': 449,
#  'alone': 450,
#  'smith': 451,
#  'enjoy': 452,
#  'van': 453,
#  'among': 454,
#  'piece': 455,
#  'none': 456,
#  'involving': 457,
#  'voice': 458,
#  'laughs': 459,
#  'laugh': 460,
#  'murder': 461,
#  'note': 462,
#  'involved': 463,
#  'mean': 464,
#  'five': 465,
#  'usually': 466,
#  'emotional': 467,
#  'words': 468,
#  'guess': 469,
#  'romantic': 470,
#  'lack': 471,
#  'talent': 472,
#  'batman': 473,
#  'scream': 474,
#  'america': 475,
#  'forced': 476,
#  'poor': 477,
#  'happen': 478,
#  'paul': 479,
#  'parents': 480,
#  'told': 481,
#  'obviously': 482,
#  'elements': 483,
#  'leads': 484,
#  'single': 485,
#  'viewer': 486,
#  'robin': 487,
#  'leave': 488,
#  'expect': 489,
#  'planet': 490,
#  'wonderful': 491,
#  'taken': 492,
#  'de': 493,
#  'within': 494,
#  'easy': 495,
#  'late': 496,
#  'word': 497,
#  'seemed': 498,
#  'talk': 499,
#  'number': 500,
#  'interest': 501,
#  'hell': 502,
#  'chance': 503,
#  'giving': 504,
#  'deal': 505,
#  'needs': 506,
#  'across': 507,
#  'george': 508,
#  'ryan': 509,
#  'premise': 510,
#  'meets': 511,
#  'power': 512,
#  'call': 513,
#  'aliens': 514,
#  'except': 515,
#  'chris': 516,
#  'feels': 517,
#  'entertainment': 518,
#  'stuff': 519,
#  'fans': 520,
#  'whether': 521,
#  'tale': 522,
#  'attempts': 523,
#  'wild': 524,
#  'williams': 525,
#  'crew': 526,
#  'parts': 527,
#  'recent': 528,
#  'apparently': 529,
#  'working': 530,
#  'score': 531,
#  'killed': 532,
#  'return': 533,
#  'events': 534,
#  'brings': 535,
#  'art': 536,
#  'surprise': 537,
#  'girls': 538,
#  'brothers': 539,
#  'science': 540,
#  'happy': 541,
#  'feature': 542,
#  'girlfriend': 543,
#  'remember': 544,
#  'release': 545,
#  'serious': 546,
#  'ago': 547,
#  'success': 548,
#  'cool': 549,
#  'william': 550,
#  'went': 551,
#  'television': 552,
#  'features': 553,
#  'impressive': 554,
#  'anyway': 555,
#  'computer': 556,
#  'local': 557,
#  '1': 558,
#  'flick': 559,
#  'sequel': 560,
#  'history': 561,
#  'due': 562,
#  'die': 563,
#  'annoying': 564,
#  'form': 565,
#  'change': 566,
#  'figure': 567,
#  'middle': 568,
#  'mission': 569,
#  'murphy': 570,
#  'somewhat': 571,
#  'crime': 572,
#  'ben': 573,
#  'important': 574,
#  'dramatic': 575,
#  'turned': 576,
#  'basically': 577,
#  'using': 578,
#  'presence': 579,
#  'usual': 580,
#  'somehow': 581,
#  'hilarious': 582,
#  'credits': 583,
#  'released': 584,
#  'came': 585,
#  'runs': 586,
#  'uses': 587,
#  'martin': 588,
#  'effective': 589,
#  'general': 590,
#  'oscar': 591,
#  'absolutely': 592,
#  'ways': 593,
#  'predictable': 594,
#  'wars': 595,
#  'quality': 596,
#  'kid': 597,
#  'decides': 598,
#  'clear': 599,
#  'complete': 600,
#  'project': 601,
#  'jim': 602,
#  'towards': 603,
#  'powerful': 604,
#  'easily': 605,
#  'actress': 606,
#  'sexual': 607,
#  'filmmakers': 608,
#  'previous': 609,
#  'read': 610,
#  'suspense': 611,
#  'oh': 612,
#  'light': 613,
#  'business': 614,
#  'visual': 615,
#  'writer': 616,
#  'similar': 617,
#  'bill': 618,
#  '3': 619,
#  'villain': 620,
#  'certain': 621,
#  'shots': 622,
#  'married': 623,
#  'nature': 624,
#  'party': 625,
#  'harry': 626,
#  'giant': 627,
#  'reality': 628,
#  'begin': 629,
#  'rich': 630,
#  'doubt': 631,
#  'means': 632,
#  'excellent': 633,
#  'successful': 634,
#  'opens': 635,
#  'leaving': 636,
#  'difficult': 637,
#  'water': 638,
#  'ones': 639,
#  'present': 640,
#  'latest': 641,
#  'talking': 642,
#  'former': 643,
#  'situation': 644,
#  'popular': 645,
#  'definitely': 646,
#  'message': 647,
#  'add': 648,
#  'romance': 649,
#  'saying': 650,
#  'starring': 651,
#  'blood': 652,
#  'red': 653,
#  'third': 654,
#  'felt': 655,
#  'stories': 656,
#  'sam': 657,
#  'personal': 658,
#  'learn': 659,
#  'bob': 660,
#  'age': 661,
#  'took': 662,
#  'follows': 663,
#  'gone': 664,
#  'secret': 665,
#  'company': 666,
#  'truman': 667,
#  'strange': 668,
#  'office': 669,
#  'near': 670,
#  'solid': 671,
#  'create': 672,
#  'large': 673,
#  'familiar': 674,
#  'type': 675,
#  'escape': 676,
#  'brilliant': 677,
#  'bruce': 678,
#  'straight': 679,
#  'writing': 680,
#  'surprisingly': 681,
#  'mystery': 682,
#  'allen': 683,
#  'bond': 684,
#  'prison': 685,
#  'smart': 686,
#  'questions': 687,
#  'clever': 688,
#  'jones': 689,
#  'huge': 690,
#  'country': 691,
#  'happened': 692,
#  'amazing': 693,
#  'bunch': 694,
#  'cop': 695,
#  'intelligent': 696,
#  'cut': 697,
#  'thinking': 698,
#  'plan': 699,
#  'following': 700,
#  'perfectly': 701,
#  'seriously': 702,
#  'cinema': 703,
#  'subject': 704,
#  'slow': 705,
#  'effect': 706,
#  'agent': 707,
#  'scary': 708,
#  '4': 709,
#  'beyond': 710,
#  'dream': 711,
#  'million': 712,
#  'situations': 713,
#  'likely': 714,
#  'mark': 715,
#  'move': 716,
#  'potential': 717,
#  'sweet': 718,
#  'viewers': 719,
#  'realize': 720,
#  'immediately': 721,
#  'scott': 722,
#  'overall': 723,
#  'decent': 724,
#  'merely': 725,
#  'leaves': 726,
#  'trouble': 727,
#  'stone': 728,
#  'appear': 729,
#  'rock': 730,
#  'follow': 731,
#  'particular': 732,
#  'motion': 733,
#  'spend': 734,
#  'unlike': 735,
#  'moving': 736,
#  'audiences': 737,
#  'created': 738,
#  'inside': 739,
#  'animated': 740,
#  'trek': 741,
#  'enjoyable': 742,
#  'west': 743,
#  'heard': 744,
#  'liked': 745,
#  'impossible': 746,
#  'wanted': 747,
#  'otherwise': 748,
#  'dumb': 749,
#  'brought': 750,
#  'park': 751,
#  'filled': 752,
#  'exciting': 753,
#  'stay': 754,
#  'r': 755,
#  'break': 756,
#  'neither': 757,
#  'steven': 758,
#  'force': 759,
#  'showing': 760,
#  '10': 761,
#  'ten': 762,
#  'wait': 763,
#  'carter': 764,
#  'british': 765,
#  'eddie': 766,
#  'points': 767,
#  'truth': 768,
#  'fails': 769,
#  'effort': 770,
#  'mess': 771,
#  'ultimately': 772,
#  'memorable': 773,
#  'various': 774,
#  'understand': 775,
#  'political': 776,
#  'today': 777,
#  'moves': 778,
#  'grace': 779,
#  'disaster': 780,
#  'studio': 781,
#  'talented': 782,
#  'soundtrack': 783,
#  'favorite': 784,
#  'slightly': 785,
#  'impact': 786,
#  'killing': 787,
#  'drug': 788,
#  'private': 789,
#  'fan': 790,
#  'gun': 791,
#  'members': 792,
#  'credit': 793,
#  'box': 794,
#  'offers': 795,
#  'subplot': 796,
#  'typical': 797,
#  'fear': 798,
#  'chase': 799,
#  'cameron': 800,
#  'mary': 801,
#  'constantly': 802,
#  'purpose': 803,
#  'wedding': 804,
#  'element': 805,
#  'hands': 806,
#  'expected': 807,
#  'max': 808,
#  'biggest': 809,
#  'keeps': 810,
#  'woody': 811,
#  'open': 812,
#  'terrible': 813,
#  'l': 814,
#  'society': 815,
#  'actual': 816,
#  'cold': 817,
#  'animation': 818,
#  'nick': 819,
#  'ideas': 820,
#  'earlier': 821,
#  'ask': 822,
#  'steve': 823,
#  'master': 824,
#  'suddenly': 825,
#  'sister': 826,
#  'army': 827,
#  'setting': 828,
#  'gave': 829,
#  'carrey': 830,
#  'government': 831,
#  'cinematography': 832,
#  'view': 833,
#  'focus': 834,
#  'musical': 835,
#  'fast': 836,
#  'control': 837,
#  'mike': 838,
#  'willis': 839,
#  'entirely': 840,
#  'totally': 841,
#  'brief': 842,
#  'aspect': 843,
#  'cheap': 844,
#  'convincing': 845,
#  'silly': 846,
#  'female': 847,
#  'amusing': 848,
#  'boys': 849,
#  'wish': 850,
#  'rating': 851,
#  'whatever': 852,
#  'ridiculous': 853,
#  'longer': 854,
#  'state': 855,
#  'hate': 856,
#  'e': 857,
#  'etc': 858,
#  'reasons': 859,
#  'dreams': 860,
#  'approach': 861,
#  'complex': 862,
#  'somewhere': 863,
#  'titanic': 864,
#  'lies': 865,
#  'beauty': 866,
#  'greatest': 867,
#  'thinks': 868,
#  'street': 869,
#  'asks': 870,
#  'seven': 871,
#  'ability': 872,
#  'free': 873,
#  'atmosphere': 874,
#  'chemistry': 875,
#  'class': 876,
#  'indeed': 877,
#  'waste': 878,
#  'sit': 879,
#  'tim': 880,
#  'air': 881,
#  'meanwhile': 882,
#  'richard': 883,
#  'pay': 884,
#  'subtle': 885,
#  'sounds': 886,
#  'spent': 887,
#  'terrific': 888,
#  'common': 889,
#  'flat': 890,
#  'slowly': 891,
#  'tension': 892,
#  'clearly': 893,
#  'hear': 894,
#  'budget': 895,
#  'frank': 896,
#  'shown': 897,
#  'u': 898,
#  'imagine': 899,
#  'spielberg': 900,
#  'caught': 901,
#  'sees': 902,
#  'tarantino': 903,
#  'eye': 904,
#  'stand': 905,
#  'plenty': 906,
#  'provide': 907,
#  'interested': 908,
#  'pace': 909,
#  'outside': 910,
#  'telling': 911,
#  'dull': 912,
#  'miss': 913,
#  'minor': 914,
#  'sight': 915,
#  'j': 916,
#  'saving': 917,
#  'ride': 918,
#  'teen': 919,
#  'fire': 920,
#  'island': 921,
#  'awful': 922,
#  'cinematic': 923,
#  'knew': 924,
#  'forget': 925,
#  'lots': 926,
#  'english': 927,
#  'apartment': 928,
#  'b': 929,
#  'godzilla': 930,
#  'sean': 931,
#  'realistic': 932,
#  'fairly': 933,
#  'possibly': 934,
#  'road': 935,
#  'charm': 936,
#  'screenwriter': 937,
#  'sent': 938,
#  'jerry': 939,
#  'development': 940,
#  'song': 941,
#  'period': 942,
#  'modern': 943,
#  'puts': 944,
#  'carry': 945,
#  'depth': 946,
#  'becoming': 947,
#  'amount': 948,
#  'trip': 949,
#  'brown': 950,
#  'simon': 951,
#  'proves': 952,
#  'climax': 953,
#  'critics': 954,
#  'chan': 955,
#  'billy': 956,
#  'quick': 957,
#  'violent': 958,
#  'language': 959,
#  'store': 960,
#  'famous': 961,
#  'cute': 962,
#  'front': 963,
#  'choice': 964,
#  'conclusion': 965,
#  'elizabeth': 966,
#  'tone': 967,
#  'okay': 968,
#  'hold': 969,
#  'highly': 970,
#  'believable': 971,
#  'theme': 972,
#  'stands': 973,
#  'learns': 974,
#  'blade': 975,
#  'decide': 976,
#  'ground': 977,
#  'recently': 978,
#  'pull': 979,
#  'appearance': 980,
#  'background': 981,
#  'missing': 982,
#  'images': 983,
#  'ii': 984,
#  'rated': 985,
#  'douglas': 986,
#  'vampire': 987,
#  'leader': 988,
#  'apart': 989,
#  'casting': 990,
#  'wasted': 991,
#  'christopher': 992,
#  'occasionally': 993,
#  'list': 994,
#  'french': 995,
#  'doctor': 996,
#  'onto': 997,
#  'delivers': 998,
#  'enjoyed': 999,
#  'aside': 1000,
#  ...}

# %%
text = """
moviemaking is a lot like being the general manager of an nfl team in the post-salary cap era -- you've got to know how to allocate your resources . 
every dollar spent on a free-agent defensive tackle is one less dollar than you can spend on linebackers or safeties or centers . 
in the nfl , this leads to teams like the detroit lions , who boast a superstar running back with a huge contract , but can only field five guys named herb to block for him . 
in the movies , you end up with films like " spawn " , with a huge special-effects budget but not enough money to hire any recognizable actors . 
jackie chan is the barry sanders of moviemaking . 
he spins and darts across the screen like sanders cutting back through the defensive line . 
watching jackie in operation condor as he drives his motorcycle through the crowded streets of madrid , fleeing an armada of pursuers in identical black compact cars , is reminiscent of sanders running for daylight with the chicago bears in hot pursuit , except that sanders doesn't have to worry about rescuing runaway baby carriages . 
but like the lions star , jackie doesn't have anybody to block for him . 
almost every cent that's invested in a jackie chan movie goes for stunts , and as chan does his own stunts , the rest of the money goes to pay his hospital bills . 
this leaves about 75 cents to pay for things like directors ( chan directs ) , scripts and dubbing and supporting characters , not to mention the hideous title sequence . 
this also explains why the movie was shot in odd places like morocco and spain . 
 ( chan's first release in this country , " rumble in the bronx " , was supposedly set in new york , but was filmed in vancouver , and in the chase scenes the canadian rockies are clearly visible . ) 
heck , jackie doesn't even have enough money for a haircut , looks like , much less a personal hairstylist . 
in condor , chan plays the same character he's always played , himself , a mixture of bruce lee and tim allen , a master of both kung-fu and slapstick-fu . 
jackie is sent by the un to retrieve a cache of lost nazi gold in the north african desert , and is chased by a horde of neo-nazi sympathizers and two stereotypical arabs ( one of the things i like about jackie chan movies : no political correctness ) . 
he is joined by three women , who have little to do except scream , " jackie , save us ! " , and misuse firearms . 
the villain is an old nazi whose legs were broken in the secret base so that he has to be carried everywhere , and he's more pathetic than evil . 
en route , we have an extended motorcycle chase scene , a hilarious fight in the moroccan version of motel 6 with the neo-nazis , and two confrontations with savage natives . 
once at the secret desert base , there is a long chop-socky sequence , followed by the film's centerpiece , a wind-tunnel fight that's even better than the one in face/off . 
this is where the money was spent , on well-choreographed kung-fu sequences , on giant kevlar hamster balls , on smashed-up crates of bananas , and on scorpions . 
ignore the gaping holes in the plot ( how , exactly , if the villain's legs were broken , did he escape from the secret nazi base , and why didn't he take the key with him ? ) . 
don't worry about the production values , or what , exactly , the japanese girl was doing hitchhiking across the sahara . 
just go see the movie . 
operation condor has pretentions of being a " raiders of the lost ark " knockoff , but one wonders what jackie could do with the raiders franchise blocking for him -- with a lawrence kazdan screenplay , a john williams score , spielberg directing and george lucas producing , condor might be an a+ movie . 
however , you've got to go with what you've got , and what you've got in jackie chan is something special -- a talent that mainstream hollywood should , could , and ought to utilize .
"""

# %%
tokens = word_tokenize(text)
translator = str.maketrans('', '', punctuation)
tokens = [w.translate(translator) for w in tokens]
tokens = [w for w in tokens if not w in stop_words]
text = ' '.join(tokens)

# %%
text
# Out:
# 'moviemaking lot like general manager nfl team postsalary cap era  got know allocate resources  every dollar spent freeagent defensive tackle one less dollar spend linebackers safeties centers  nfl  leads teams like detroit lions  boast superstar running back huge contract  field five guys named herb block  movies  end films like  spawn   huge specialeffects budget enough money hire recognizable actors  jackie chan barry sanders moviemaking  spins darts across screen like sanders cutting back defensive line  watching jackie operation condor drives motorcycle crowded streets madrid  fleeing armada pursuers identical black compact cars  reminiscent sanders running daylight chicago bears hot pursuit  except sanders nt worry rescuing runaway baby carriages  like lions star  jackie nt anybody block  almost every cent invested jackie chan movie goes stunts  chan stunts  rest money goes pay hospital bills  leaves 75 cents pay things like directors  chan directs   scripts dubbing supporting characters  mention hideous title sequence  also explains movie shot odd places like morocco spain   chan first release country   rumble bronx   supposedly set new york  filmed vancouver  chase scenes canadian rockies clearly visible   heck  jackie nt even enough money haircut  looks like  much less personal hairstylist  condor  chan plays character always played   mixture bruce lee tim allen  master kungfu slapstickfu  jackie sent un retrieve cache lost nazi gold north african desert  chased horde neonazi sympathizers two stereotypical arabs  one things like jackie chan movies  political correctness   joined three women  little except scream   jackie  save us    misuse firearms  villain old nazi whose legs broken secret base carried everywhere  pathetic evil  en route  extended motorcycle chase scene  hilarious fight moroccan version motel 6 neonazis  two confrontations savage natives  secret desert base  long chopsocky sequence  followed film centerpiece  windtunnel fight even better one faceoff  money spent  wellchoreographed kungfu sequences  giant kevlar hamster balls  smashedup crates bananas  scorpions  ignore gaping holes plot   exactly  villain legs broken  escape secret nazi base  nt take key    nt worry production values   exactly  japanese girl hitchhiking across sahara  go see movie  operation condor pretentions  raiders lost ark  knockoff  one wonders jackie could raiders franchise blocking  lawrence kazdan screenplay  john williams score  spielberg directing george lucas producing  condor might movie  however  got go got  got jackie chan something special  talent mainstream hollywood  could  ought utilize '

# %%
text = tokenizer.texts_to_sequences([text])[0]
text
# Out:
# [5040,
#  106,
#  5,
#  590,
#  3175,
#  17147,
#  347,
#  6604,
#  1611,
#  170,
#  37,
#  5688,
#  56,
#  2450,
#  887,
#  13140,
#  8231,
#  4,
#  189,
#  2450,
#  734,
#  4231,
#  17147,
#  484,
#  4587,
#  5,
#  7265,
#  7158,
#  7520,
#  8313,
#  349,
#  52,
#  690,
#  6125,
#  1440,
#  465,
#  402,
#  277,
#  2678,
#  38,
#  49,
#  25,
#  5,
#  1248,
#  690,
#  16929,
#  895,
#  62,
#  173,
#  4310,
#  6750,
#  104,
#  351,
#  955,
#  2296,
#  13438,
#  5040,
#  13273,
#  32654,
#  507,
#  120,
#  5,
#  13438,
#  3111,
#  52,
#  13140,
#  224,
#  168,
#  351,
#  2866,
#  9036,
#  2486,
#  7094,
#  8802,
#  1879,
#  5853,
#  39930,
#  10563,
#  7001,
#  171,
#  13775,
#  2188,
#  1973,
#  13438,
#  349,
#  3858,
#  2113,
#  3677,
#  1196,
#  3831,
#  515,
#  13438,
#  2,
#  3438,
#  10805,
#  8081,
#  1030,
#  5,
#  7158,
#  102,
#  351,
#  2,
#  2922,
#  2678,
#  83,
#  56,
#  40143,
#  6395,
#  351,
#  955,
#  3,
#  116,
#  2009,
#  955,
#  2009,
#  203,
#  173,
#  116,
#  884,
#  1601,
#  8161,
#  726,
#  10286,
#  12017,
#  884,
#  76,
#  5,
#  1134,
#  955,
#  2965,
#  3644,
#  8669,
#  374,
#  15,
#  1131,
#  5018,
#  339,
#  239,
#  14,
#  1914,
#  3,
#  300,
#  1064,
#  1282,
#  5,
#  14995,
#  6149,
#  955,
#  17,
#  545,
#  691,
#  4000,
#  6406,
#  1910,
#  148,
#  34,
#  357,
#  1191,
#  18960,
#  799,
#  36,
#  3945,
#  31643,
#  893,
#  14175,
#  3361,
#  351,
#  2,
#  6,
#  62,
#  173,
#  16784,
#  195,
#  5,
#  11,
#  189,
#  658,
#  9036,
#  955,
#  91,
#  12,
#  137,
#  84,
#  5724,
#  678,
#  378,
#  880,
#  683,
#  824,
#  8851,
#  351,
#  938,
#  8983,
#  5873,
#  14201,
#  238,
#  4356,
#  1534,
#  3041,
#  4012,
#  2298,
#  3936,
#  18753,
#  37246,
#  16,
#  2343,
#  4,
#  76,
#  5,
#  351,
#  955,
#  38,
#  776,
#  14663,
#  4872,
#  126,
#  363,
#  26,
#  515,
#  474,
#  351,
#  372,
#  43,
#  24061,
#  14200,
#  620,
#  94,
#  4356,
#  204,
#  3031,
#  1886,
#  665,
#  3236,
#  3282,
#  2655,
#  1255,
#  185,
#  9198,
#  4259,
#  2473,
#  7094,
#  799,
#  29,
#  582,
#  307,
#  36823,
#  358,
#  6589,
#  2057,
#  16,
#  12059,
#  4133,
#  8419,
#  665,
#  2298,
#  3236,
#  98,
#  22276,
#  239,
#  1722,
#  1,
#  13761,
#  307,
#  6,
#  63,
#  4,
#  5904,
#  173,
#  887,
#  15606,
#  8851,
#  337,
#  627,
#  26375,
#  5249,
#  27172,
#  8791,
#  3948,
#  8578,
#  1972,
#  28,
#  356,
#  620,
#  3031,
#  1886,
#  676,
#  665,
#  4356,
#  3236,
#  2,
#  65,
#  1049,
#  2,
#  3438,
#  334,
#  2274,
#  356,
#  1432,
#  201,
#  26838,
#  507,
#  11109,
#  44,
#  18,
#  3,
#  2866,
#  9036,
#  18278,
#  6913,
#  238,
#  4995,
#  7413,
#  4,
#  2347,
#  351,
#  22,
#  6913,
#  2720,
#  18727,
#  1727,
#  346,
#  86,
#  525,
#  531,
#  900,
#  1023,
#  508,
#  1078,
#  4325,
#  9036,
#  118,
#  3,
#  55,
#  170,
#  44,
#  170,
#  170,
#  351,
#  955,
#  51,
#  147,
#  472,
#  2572,
#  138,
#  22,
#  7177,
#  7642]

# %%
text = pad_sequences([text], maxlen=max_len, padding='post')
text
# Out:
# array([[5040,  106,    5, ...,    0,    0,    0]])

# %%
model.predict(text)
# Out:
# 1/1 [==============================] - 0s 124ms/step
# array([[0.00558658]], dtype=float32)

# %%
pred = model.predict(text)
if float(pred) > 0.5:
    print('Positive')
else:
    print('Negative')
# Out:
# 1/1 [==============================] - 0s 17ms/step
# Negative
# C:\Users\Elnaz Parsaei\AppData\Local\Temp\ipykernel_14656\1560334435.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   if float(pred) > 0.5:

# %%
# MasoudKaviani.ir
