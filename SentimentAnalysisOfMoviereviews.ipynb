# %%
# !pip install nltk
# Out:
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: click in c:\users\elnaz parsaei\.conda\envs\tf\lib\site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in c:\users\elnaz parsaei\.conda\envs\tf\lib\site-packages (from nltk) (1.4.0)
# Collecting regex>=2021.8.3 (from nltk)
#   Downloading regex-2024.5.15-cp310-cp310-win_amd64.whl.metadata (41 kB)
#      ---------------------------------------- 0.0/42.0 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/42.0 kB ? eta -:--:--
#      ------------------ ------------------- 20.5/42.0 kB 217.9 kB/s eta 0:00:01
#      ------------------ ------------------- 20.5/42.0 kB 217.9 kB/s eta 0:00:01
#      -------------------------------------  41.0/42.0 kB 219.4 kB/s eta 0:00:01
#      -------------------------------------- 42.0/42.0 kB 203.4 kB/s eta 0:00:00
# Requirement already satisfied: tqdm in c:\users\elnaz parsaei\.conda\envs\tf\lib\site-packages (from nltk) (4.49.0)
# Requirement already satisfied: colorama in c:\users\elnaz parsaei\.conda\envs\tf\lib\site-packages (from click->nltk) (0.4.6)
# Using cached nltk-3.8.1-py3-none-any.whl (1.5 MB)
# Downloading regex-2024.5.15-cp310-cp310-win_amd64.whl (268 kB)
#    ---------------------------------------- 0.0/269.0 kB ? eta -:--:--
#    - -------------------------------------- 10.2/269.0 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/269.0 kB 435.7 kB/s eta 0:00:01
#    ----- --------------------------------- 41.0/269.0 kB 326.8 kB/s eta 0:00:01
#    -------- ------------------------------ 61.4/269.0 kB 409.6 kB/s eta 0:00:01
#    ---------- ---------------------------- 71.7/269.0 kB 393.8 kB/s eta 0:00:01
#    -------------- ----------------------- 102.4/269.0 kB 420.8 kB/s eta 0:00:01
#    ----------------- -------------------- 122.9/269.0 kB 450.6 kB/s eta 0:00:01
#    ------------------ ------------------- 133.1/269.0 kB 437.3 kB/s eta 0:00:01
#    --------------------- ---------------- 153.6/269.0 kB 437.1 kB/s eta 0:00:01
#    ------------------------ ------------- 174.1/269.0 kB 456.4 kB/s eta 0:00:01
#    -------------------------- ----------- 184.3/269.0 kB 445.2 kB/s eta 0:00:01
#    ---------------------------- --------- 204.8/269.0 kB 461.0 kB/s eta 0:00:01
#    ------------------------------ ------- 215.0/269.0 kB 452.1 kB/s eta 0:00:01
#    --------------------------------- ---- 235.5/269.0 kB 465.5 kB/s eta 0:00:01
#    -------------------------------------- 269.0/269.0 kB 459.6 kB/s eta 0:00:00
# Installing collected packages: regex, nltk
# Successfully installed nltk-3.8.1 regex-2024.5.15

# %%
import os
from nltk.corpus import stopwords
from nltk import word_tokenize
from string import punctuation
import random

# %%
os.listdir('data/neg')
# Out:
# ['.ipynb_checkpoints',
#  'cv000_29416.txt',
#  'cv001_19502.txt',
#  'cv002_17424.txt',
#  'cv003_12683.txt',
#  'cv004_12641.txt',
#  'cv005_29357.txt',
#  'cv006_17022.txt',
#  'cv007_4992.txt',
#  'cv008_29326.txt',
#  'cv009_29417.txt',
#  'cv010_29063.txt',
#  'cv011_13044.txt',
#  'cv012_29411.txt',
#  'cv013_10494.txt',
#  'cv014_15600.txt',
#  'cv015_29356.txt',
#  'cv016_4348.txt',
#  'cv017_23487.txt',
#  'cv018_21672.txt',
#  'cv019_16117.txt',
#  'cv020_9234.txt',
#  'cv021_17313.txt',
#  'cv022_14227.txt',
#  'cv023_13847.txt',
#  'cv024_7033.txt',
#  'cv025_29825.txt',
#  'cv026_29229.txt',
#  'cv027_26270.txt',
#  'cv028_26964.txt',
#  'cv029_19943.txt',
#  'cv030_22893.txt',
s = str.maketrans('', '', punctuation)#tranlator
a = 'salam!@'
a.translate(s)
# Out:
# 'salam'

# %%
stop_words = stopwords.words('english')

# %%
negative_documents = []
max_len_negative = 0
for file in os.listdir('data/neg'):
    if not file.endswith('ipynb_checkpoints'):
        with open('data/neg/' + file) as f:
            text = f.read()
            tokens = word_tokenize(text)
            translator = str.maketrans('', '', punctuation)
            tokens = [w.translate(translator) for w in tokens]
            tokens = [w for w in tokens if not w in stop_words]
            if len(tokens) > max_len_negative:
                max_len_negative = len(tokens)
            negative_documents.append(' '.join(tokens))
len(negative_documents)
# Out:
# 1000

# %%
max_len_negative
# Out:
# 1400

# %%
positive_documents = []
max_len_positive = 0
for file in os.listdir('data/pos'):
    with open('data/pos/' + file) as f:
        text = f.read()
        tokens = word_tokenize(text)
        translator = str.maketrans('', '', punctuation)
        tokens = [w.translate(translator) for w in tokens]
        tokens = [w for w in tokens if not w in stop_words]
        if len(tokens) > max_len_positive:
            max_len_positive = len(tokens)
        positive_documents.append(' '.join(tokens))
len(positive_documents)
# Out:
# 1000

# %%
max_len_positive
# Out:
# 1693

# %%
max_len = max(max_len_negative, max_len_positive)

# %%
random.shuffle(negative_documents)
random.shuffle(positive_documents)

# %%
X_train = negative_documents[:800] + positive_documents[:800]

# %%
len(X_train)
# Out:
# 1600

# %%
y_train = [0 for _ in range(800)] + [1 for _ in range(800)]

# %%
len(y_train)
# Out:
# 1600

# %%
X_test = negative_documents[800:] + positive_documents[800:]
len(X_test)
# Out:
# 400

# %%
y_test = [0 for _ in range(200)] + [1 for _ in range(200)]

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Dense, Flatten, Embedding, Conv1D, MaxPool1D, Dropout
from tensorflow.keras.layers import concatenate

# %%
max_len
# Out:
# 1693

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(X_train)

# %%
import pickle
with open('tokenizer.h5', 'wb') as f:
    pickle.dump(tokenizer, f)

# %%
tokenizer

# %%
vocab_len = len(tokenizer.word_index) + 1

# %%
vocab_len
# Out:
# 40606

# %%
encoded = tokenizer.texts_to_sequences(X_train)

# %%
encoded[0]
# Out:
# [1,
#  999,
#  14979,
#  881,
#  215,
#  12918,
#  544,
#  439,
#  10,
#  1247,
#  1933,
#  507,
#  1733,
#  6131,
#  3423,
#  3,
#  145,
#  1248,
#  7366,
#  631,
#  10187,
#  4057,
#  35,
#  137,
#  12919,
#  129,
#  1398,
#  965,
#  5505,
#  833,
#  84,
#  5506,
#  20,
#  6478,
#  116,
#  1867,
#  6869,
#  106,
#  1347,
#  948,
#  3643,
#  3,
#  472,
#  966,
#  1058,
#  395,
#  332,
#  3,
#  9251,
#  1564,
#  493,
#  3,
#  2530,
#  641,
#  7367,
#  324,
#  12920,
#  23934,
#  4401,
#  1537,
#  42,
#  780,
#  68,
#  4,
#  642,
#  26,
#  1,
#  3,
#  10188,
#  1517,
#  1185,
#  9252,
#  11330,
#  18200,
#  2876,
#  14980,
#  1028,
#  228,
#  10,
#  9251,
#  6870,
#  23935,
#  9251,
#  4782,
#  12920,
#  4584,
#  12920,
#  94,
#  171,
#  677,
#  1,
#  821,
#  5803,
#  2591,
#  16,
#  399,
#  48,
#  670,
#  102,
#  3220,
#  2093,
#  1,
#  74,
#  1445,
#  30,
#  6871,
#  1,
#  104,
#  5804,
#  10,
#  10189,
#  650,
#  1226,
#  30,
#  144,
#  3,
#  6132,
#  12921,
#  3,
#  292,
#  12922,
#  1,
#  4996,
#  27,
#  1186,
#  18201,
#  3424,
#  3,
#  2954,
#  23936,
#  439,
#  10,
#  120,
#  1679,
#  137,
#  10,
#  307,
#  4402,
#  876,
#  50,
#  2362,
#  1518,
#  23937,
#  43,
#  231,
#  9,
#  1174,
#  32,
#  202,
#  3920,
#  1679,
#  18202,
#  9251,
#  40,
#  32,
#  1227,
#  9251,
#  23938,
#  1972,
#  31,
#  1322,
#  182,
#  12923,
#  6872,
#  103,
#  4208,
#  3921,
#  14981,
#  627,
#  4997,
#  1972,
#  867,
#  220,
#  2094,
#  166,
#  4783,
#  23939,
#  4,
#  323,
#  967,
#  23940,
#  23941,
#  2402,
#  696,
#  395,
#  643,
#  410,
#  18203,
#  489,
#  9251,
#  3784,
#  4058,
#  270,
#  5507,
#  3922,
#  26,
#  6479,
#  3,
#  1802,
#  7,
#  632,
#  2260,
#  473,
#  176,
#  949,
#  448,
#  544,
#  3425,
#  48,
#  3,
#  8488,
#  9251,
#  602,
#  549,
#  6873,
#  1,
#  4209,
#  793,
#  5246,
#  1110,
#  9,
#  803,
#  339,
#  1803,
#  9,
#  3644,
#  1132,
#  1399]

# %%
padded = pad_sequences(encoded, maxlen=max_len, padding='post')

# %%
padded.shape
# Out:
# (1600, 1693)

# %%
input1 = Input(shape=(max_len,))
embedding1 = Embedding(vocab_len, 100)(input1)
conv1 = Conv1D(filters=32, kernel_size=4, activation='relu')(embedding1)
drop1 = Dropout(0.5)(conv1)
pool1 = MaxPool1D(pool_size=2)(drop1)
flat1 = Flatten()(pool1)
dense1 = Dense(10, activation='relu')(flat1)
output = Dense(1, activation='sigmoid')(dense1)

# %%
model = Model(inputs=[input1], outputs=output)

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 1693)]            0
#
#  embedding (Embedding)       (None, 1693, 100)         4060600
#
#  conv1d (Conv1D)             (None, 1690, 32)          12832
#
#  dropout (Dropout)           (None, 1690, 32)          0
#
#  max_pooling1d (MaxPooling1D  (None, 845, 32)          0
#  )
#
#  flatten (Flatten)           (None, 27040)             0
#
#  dense (Dense)               (None, 10)                270410
#
#  dense_1 (Dense)             (None, 1)                 11
#
# =================================================================
# Total params: 4,343,853
# Trainable params: 4,343,853
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(model, show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
encoded_test = tokenizer.texts_to_sequences(X_test)
padded_test = pad_sequences(encoded_test, maxlen=max_len, padding='post')

# %%
padded_test.shape
# Out:
# (400, 1693)

# %%
import numpy as np

# %%
model.fit([padded], np.array(y_train), epochs=10, batch_size=20, validation_data=([padded_test], np.array(y_test)))
# Out:
# Epoch 1/10
# 80/80 [==============================] - 8s 85ms/step - loss: 0.6959 - accuracy: 0.5013 - val_loss: 0.6896 - val_accuracy: 0.4975
# Epoch 2/10
# 80/80 [==============================] - 6s 74ms/step - loss: 0.6567 - accuracy: 0.6288 - val_loss: 0.6590 - val_accuracy: 0.6025
# Epoch 3/10
# 80/80 [==============================] - 6s 75ms/step - loss: 0.2285 - accuracy: 0.9613 - val_loss: 0.4764 - val_accuracy: 0.7575
# Epoch 4/10
# 80/80 [==============================] - 7s 86ms/step - loss: 0.0139 - accuracy: 0.9987 - val_loss: 0.4218 - val_accuracy: 0.8275
# Epoch 5/10
# 80/80 [==============================] - 6s 75ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.4170 - val_accuracy: 0.8275
# Epoch 6/10
# 80/80 [==============================] - 6s 77ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.4230 - val_accuracy: 0.8075
# Epoch 7/10
# 80/80 [==============================] - 6s 80ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.4219 - val_accuracy: 0.8350
# Epoch 8/10
# 80/80 [==============================] - 6s 77ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.4240 - val_accuracy: 0.8200
# Epoch 9/10
# 80/80 [==============================] - 7s 84ms/step - loss: 7.8045e-04 - accuracy: 1.0000 - val_loss: 0.4255 - val_accuracy: 0.8275
# Epoch 10/10
# 80/80 [==============================] - 7s 84ms/step - loss: 6.5335e-04 - accuracy: 1.0000 - val_loss: 0.4268 - val_accuracy: 0.8375

# %%
model.save('textcnn.h5')

# %%
from tensorflow.keras.models import load_model

# %%
model = load_model('textcnn.h5')

# %%
with open('tokenizer.h5', 'rb') as f:
    tokenizer = pickle.load(f)

# %%
tokenizer.word_index
# Out:
# {'film': 1,
#  'nt': 2,
#  'movie': 3,
#  'one': 4,
#  'like': 5,
#  'even': 6,
#  'good': 7,
#  'time': 8,
#  'would': 9,
#  'story': 10,
#  'much': 11,
#  'also': 12,
#  'character': 13,
#  'get': 14,
#  'characters': 15,
#  'two': 16,
#  'first': 17,
#  'see': 18,
#  'well': 19,
#  'way': 20,
#  'could': 21,
#  'make': 22,
#  'really': 23,
#  'films': 24,
#  'plot': 25,
#  'life': 26,
#  'little': 27,
#  'people': 28,
#  'never': 29,
#  'bad': 30,
#  'man': 31,
#  'scene': 32,
#  'best': 33,
#  'new': 34,
#  'many': 35,
#  'know': 36,
#  'scenes': 37,
#  'movies': 38,
#  'great': 39,
#  'another': 40,
#  'director': 41,
#  'love': 42,
#  'us': 43,
#  'action': 44,
#  'something': 45,
#  'go': 46,
#  'end': 47,
#  'made': 48,
#  'work': 49,
#  'seems': 50,
#  'still': 51,
#  'back': 52,
#  'world': 53,
#  'makes': 54,
#  'big': 55,
#  'however': 56,
#  'every': 57,
#  'better': 58,
#  'enough': 59,
#  'audience': 60,
#  'though': 61,
#  'performance': 62,
#  'around': 63,
#  'seen': 64,
#  'role': 65,
#  'take': 66,
#  'real': 67,
#  'last': 68,
#  'gets': 69,
#  'look': 70,
#  'going': 71,
#  'think': 72,
#  'actually': 73,
#  'may': 74,
#  'years': 75,
#  'john': 76,
#  'things': 77,
#  'say': 78,
#  'thing': 79,
#  'funny': 80,
#  'nothing': 81,
#  'comedy': 82,
#  'although': 83,
#  'find': 84,
#  'almost': 85,
#  'played': 86,
#  'right': 87,
#  'fact': 88,
#  'script': 89,
#  'since': 90,
#  'cast': 91,
#  'come': 92,
#  'original': 93,
#  'young': 94,
#  'long': 95,
#  'ever': 96,
#  'year': 97,
#  'plays': 98,
#  'show': 99,
#  'old': 100,
#  'comes': 101,
#  'without': 102,
#  'part': 103,
#  'acting': 104,
#  'actors': 105,
#  'least': 106,
#  'takes': 107,
#  'lot': 108,
#  'point': 109,
#  'star': 110,
#  'interesting': 111,
#  'goes': 112,
#  'guy': 113,
#  'family': 114,
#  'three': 115,
#  'course': 116,
#  'effects': 117,
#  'ca': 118,
#  'away': 119,
#  'quite': 120,
#  'far': 121,
#  'day': 122,
#  'minutes': 123,
#  'must': 124,
#  'anything': 125,
#  'might': 126,
#  'screen': 127,
#  'place': 128,
#  'watch': 129,
#  'yet': 130,
#  'rather': 131,
#  'trying': 132,
#  'wife': 133,
#  'instead': 134,
#  'special': 135,
#  'bit': 136,
#  'times': 137,
#  'fun': 138,
#  'sense': 139,
#  'always': 140,
#  'seem': 141,
#  'making': 142,
#  'job': 143,
#  'home': 144,
#  'give': 145,
#  'hollywood': 146,
#  'want': 147,
#  'becomes': 148,
#  'probably': 149,
#  'actor': 150,
#  'series': 151,
#  'picture': 152,
#  'become': 153,
#  'dialogue': 154,
#  'set': 155,
#  'kind': 156,
#  'help': 157,
#  'hard': 158,
#  'woman': 159,
#  'along': 160,
#  'pretty': 161,
#  'american': 162,
#  'given': 163,
#  'gives': 164,
#  'sure': 165,
#  'everything': 166,
#  'men': 167,
#  'whole': 168,
#  'together': 169,
#  'money': 170,
#  'got': 171,
#  'everyone': 172,
#  'black': 173,
#  'perhaps': 174,
#  'feel': 175,
#  'watching': 176,
#  'father': 177,
#  'high': 178,
#  'less': 179,
#  'music': 180,
#  'done': 181,
#  'next': 182,
#  'death': 183,
#  'especially': 184,
#  'wants': 185,
#  'horror': 186,
#  'play': 187,
#  'performances': 188,
#  'ending': 189,
#  'city': 190,
#  'evil': 191,
#  'looking': 192,
#  'looks': 193,
#  'reason': 194,
#  'moments': 195,
#  'simply': 196,
#  'mother': 197,
#  'sex': 198,
#  'humor': 199,
#  'case': 200,
#  'human': 201,
#  'completely': 202,
#  'left': 203,
#  'rest': 204,
#  'michael': 205,
#  'whose': 206,
#  'different': 207,
#  'night': 208,
#  'james': 209,
#  'lost': 210,
#  'mind': 211,
#  'shows': 212,
#  'let': 213,
#  'several': 214,
#  'couple': 215,
#  'half': 216,
#  'small': 217,
#  'entire': 218,
#  'anyone': 219,
#  'girl': 220,
#  'put': 221,
#  'turns': 222,
#  'town': 223,
#  '2': 224,
#  'problem': 225,
#  'use': 226,
#  'line': 227,
#  'true': 228,
#  'house': 229,
#  'friend': 230,
#  'else': 231,
#  'soon': 232,
#  'comic': 233,
#  'someone': 234,
#  'thought': 235,
#  'getting': 236,
#  'main': 237,
#  'found': 238,
#  'either': 239,
#  'david': 240,
#  'idea': 241,
#  'stars': 242,
#  'name': 243,
#  'tries': 244,
#  'used': 245,
#  'friends': 246,
#  'unfortunately': 247,
#  'alien': 248,
#  'based': 249,
#  'written': 250,
#  'dead': 251,
#  'final': 252,
#  'summer': 253,
#  'later': 254,
#  'wrong': 255,
#  'keep': 256,
#  'relationship': 257,
#  'called': 258,
#  'turn': 259,
#  'said': 260,
#  'boy': 261,
#  'begins': 262,
#  'second': 263,
#  'group': 264,
#  'maybe': 265,
#  'sequence': 266,
#  'tv': 267,
#  'head': 268,
#  'often': 269,
#  'certainly': 270,
#  'named': 271,
#  'works': 272,
#  'book': 273,
#  'believe': 274,
#  'past': 275,
#  'playing': 276,
#  'school': 277,
#  'behind': 278,
#  'joe': 279,
#  'finally': 280,
#  'despite': 281,
#  'children': 282,
#  'war': 283,
#  'finds': 284,
#  'game': 285,
#  'days': 286,
#  'including': 287,
#  'need': 288,
#  'able': 289,
#  'tell': 290,
#  'hand': 291,
#  'shot': 292,
#  'person': 293,
#  'lives': 294,
#  'nice': 295,
#  'perfect': 296,
#  'son': 297,
#  'live': 298,
#  'seeing': 299,
#  'matter': 300,
#  'camera': 301,
#  'daughter': 302,
#  'side': 303,
#  'kids': 304,
#  'kevin': 305,
#  'mr': 306,
#  'full': 307,
#  'supposed': 308,
#  'worth': 309,
#  'worst': 310,
#  'start': 311,
#  'running': 312,
#  'hour': 313,
#  'moment': 314,
#  'lines': 315,
#  'style': 316,
#  'run': 317,
#  'short': 318,
#  'try': 319,
#  'opening': 320,
#  'starts': 321,
#  'entertaining': 322,
#  'example': 323,
#  'directed': 324,
#  'dark': 325,
#  'upon': 326,
#  'production': 327,
#  'face': 328,
#  'version': 329,
#  'top': 330,
#  'fight': 331,
#  'review': 332,
#  'already': 333,
#  'team': 334,
#  'major': 335,
#  'disney': 336,
#  'car': 337,
#  'exactly': 338,
#  'violence': 339,
#  'sequences': 340,
#  'kill': 341,
#  'killer': 342,
#  'nearly': 343,
#  'four': 344,
#  'care': 345,
#  'throughout': 346,
#  'beautiful': 347,
#  'classic': 348,
#  'screenplay': 349,
#  'robert': 350,
#  'obvious': 351,
#  'hit': 352,
#  'title': 353,
#  'lee': 354,
#  'act': 355,
#  'deep': 356,
#  'save': 357,
#  'early': 358,
#  'problems': 359,
#  'simple': 360,
#  'space': 361,
#  'fine': 362,
#  'guys': 363,
#  'attempt': 364,
#  'coming': 365,
#  'ship': 366,
#  'roles': 367,
#  'direction': 368,
#  'video': 369,
#  'child': 370,
#  'drama': 371,
#  'order': 372,
#  'jackie': 373,
#  'question': 374,
#  'jack': 375,
#  'white': 376,
#  'others': 377,
#  'supporting': 378,
#  'knows': 379,
#  'genre': 380,
#  'jokes': 381,
#  'earth': 382,
#  'wo': 383,
#  'husband': 384,
#  'beginning': 385,
#  'sometimes': 386,
#  'stupid': 387,
#  'quickly': 388,
#  'happens': 389,
#  'scream': 390,
#  'eyes': 391,
#  'ends': 392,
#  'voice': 393,
#  'dr': 394,
#  'heart': 395,
#  'truly': 396,
#  'brother': 397,
#  'yes': 398,
#  'women': 399,
#  'peter': 400,
#  'tom': 401,
#  'hope': 402,
#  'known': 403,
#  'hero': 404,
#  'strong': 405,
#  'sort': 406,
#  'paul': 407,
#  'dog': 408,
#  'york': 409,
#  'body': 410,
#  'alone': 411,
#  'particularly': 412,
#  'fiction': 413,
#  'worse': 414,
#  'says': 415,
#  'novel': 416,
#  'manages': 417,
#  'de': 418,
#  'hours': 419,
#  'saw': 420,
#  'possible': 421,
#  'lead': 422,
#  'boring': 423,
#  'level': 424,
#  'mostly': 425,
#  'appears': 426,
#  'thriller': 427,
#  'five': 428,
#  'extremely': 429,
#  'result': 430,
#  'romantic': 431,
#  'room': 432,
#  'material': 433,
#  'planet': 434,
#  'sets': 435,
#  'god': 436,
#  'stop': 437,
#  'emotional': 438,
#  'tells': 439,
#  'attention': 440,
#  'career': 441,
#  'close': 442,
#  'television': 443,
#  'wonder': 444,
#  'mission': 445,
#  'murder': 446,
#  'police': 447,
#  'talk': 448,
#  'piece': 449,
#  'among': 450,
#  'experience': 451,
#  'battle': 452,
#  'deal': 453,
#  'involved': 454,
#  'sound': 455,
#  'leads': 456,
#  'lack': 457,
#  'success': 458,
#  'future': 459,
#  'taking': 460,
#  'eventually': 461,
#  'smith': 462,
#  'living': 463,
#  'interest': 464,
#  'elements': 465,
#  'fall': 466,
#  'meet': 467,
#  'usually': 468,
#  'aliens': 469,
#  'involving': 470,
#  'king': 471,
#  'fans': 472,
#  'theater': 473,
#  'power': 474,
#  'laugh': 475,
#  'taken': 476,
#  'word': 477,
#  'expect': 478,
#  'across': 479,
#  'single': 480,
#  'chris': 481,
#  'obviously': 482,
#  'change': 483,
#  'feels': 484,
#  'bring': 485,
#  'falls': 486,
#  'killed': 487,
#  'late': 488,
#  'tale': 489,
#  'talent': 490,
#  'history': 491,
#  'sequel': 492,
#  'recent': 493,
#  'mean': 494,
#  'feeling': 495,
#  'number': 496,
#  'needs': 497,
#  'stuff': 498,
#  'attempts': 499,
#  'guess': 500,
#  'within': 501,
#  'crew': 502,
#  'wonderful': 503,
#  'science': 504,
#  'apparently': 505,
#  'girlfriend': 506,
#  'easy': 507,
#  'features': 508,
#  'williams': 509,
#  'note': 510,
#  'impressive': 511,
#  'giving': 512,
#  'forced': 513,
#  'serious': 514,
#  'call': 515,
#  'none': 516,
#  'viewer': 517,
#  'hell': 518,
#  'basically': 519,
#  'parents': 520,
#  'enjoy': 521,
#  'seemed': 522,
#  'form': 523,
#  'chance': 524,
#  'entertainment': 525,
#  'ben': 526,
#  'laughs': 527,
#  'happy': 528,
#  'meets': 529,
#  'feature': 530,
#  'premise': 531,
#  'poor': 532,
#  'leave': 533,
#  'van': 534,
#  'cool': 535,
#  'important': 536,
#  'wars': 537,
#  'release': 538,
#  'parts': 539,
#  'local': 540,
#  'wild': 541,
#  'events': 542,
#  'brings': 543,
#  'filmmakers': 544,
#  'somehow': 545,
#  'surprise': 546,
#  'william': 547,
#  'hilarious': 548,
#  '1': 549,
#  'flick': 550,
#  'writing': 551,
#  'return': 552,
#  'quality': 553,
#  'george': 554,
#  'suspense': 555,
#  'presence': 556,
#  'score': 557,
#  'except': 558,
#  'told': 559,
#  'computer': 560,
#  'ago': 561,
#  'went': 562,
#  'girls': 563,
#  'released': 564,
#  'difficult': 565,
#  'business': 566,
#  'whether': 567,
#  'happen': 568,
#  'cinema': 569,
#  'art': 570,
#  '3': 571,
#  'working': 572,
#  'words': 573,
#  'absolutely': 574,
#  'america': 575,
#  'company': 576,
#  'complete': 577,
#  'general': 578,
#  'certain': 579,
#  'dramatic': 580,
#  'crime': 581,
#  'ryan': 582,
#  'mystery': 583,
#  'using': 584,
#  'easily': 585,
#  'turned': 586,
#  'bob': 587,
#  'shots': 588,
#  'credits': 589,
#  'uses': 590,
#  'oh': 591,
#  'giant': 592,
#  'figure': 593,
#  'excellent': 594,
#  'sam': 595,
#  'nature': 596,
#  'amazing': 597,
#  'gone': 598,
#  'red': 599,
#  'remember': 600,
#  'robin': 601,
#  'runs': 602,
#  'create': 603,
#  'annoying': 604,
#  'predictable': 605,
#  'oscar': 606,
#  'begin': 607,
#  'effective': 608,
#  'secret': 609,
#  'project': 610,
#  'potential': 611,
#  'beyond': 612,
#  'somewhat': 613,
#  'previous': 614,
#  'brothers': 615,
#  'batman': 616,
#  'popular': 617,
#  'due': 618,
#  'die': 619,
#  'clever': 620,
#  'latest': 621,
#  'anyway': 622,
#  'means': 623,
#  'kid': 624,
#  'middle': 625,
#  'personal': 626,
#  'blood': 627,
#  'sexual': 628,
#  'rock': 629,
#  'carter': 630,
#  'usual': 631,
#  'felt': 632,
#  'read': 633,
#  'reality': 634,
#  'plan': 635,
#  'surprisingly': 636,
#  'following': 637,
#  'brilliant': 638,
#  'water': 639,
#  'strange': 640,
#  'talking': 641,
#  'third': 642,
#  'cut': 643,
#  'decides': 644,
#  'successful': 645,
#  'jones': 646,
#  'similar': 647,
#  'writer': 648,
#  'bunch': 649,
#  'visual': 650,
#  'powerful': 651,
#  'actress': 652,
#  'solid': 653,
#  'clear': 654,
#  'light': 655,
#  'rich': 656,
#  'jim': 657,
#  'martin': 658,
#  'realize': 659,
#  'leaves': 660,
#  'situation': 661,
#  'prison': 662,
#  'animated': 663,
#  'smart': 664,
#  'seriously': 665,
#  'familiar': 666,
#  'message': 667,
#  'intelligent': 668,
#  'age': 669,
#  'present': 670,
#  'office': 671,
#  'scary': 672,
#  'ways': 673,
#  'starring': 674,
#  'heard': 675,
#  'million': 676,
#  'learn': 677,
#  'villain': 678,
#  'romance': 679,
#  'cameron': 680,
#  'add': 681,
#  'towards': 682,
#  'former': 683,
#  'questions': 684,
#  'impossible': 685,
#  'stories': 686,
#  'unlike': 687,
#  'near': 688,
#  'fails': 689,
#  'type': 690,
#  'saying': 691,
#  'mark': 692,
#  'leaving': 693,
#  'dream': 694,
#  'created': 695,
#  'large': 696,
#  'decent': 697,
#  'moving': 698,
#  'doubt': 699,
#  'came': 700,
#  'pay': 701,
#  'straight': 702,
#  'agent': 703,
#  'force': 704,
#  'dumb': 705,
#  'mars': 706,
#  'definitely': 707,
#  'stay': 708,
#  'audiences': 709,
#  'move': 710,
#  'subject': 711,
#  'murphy': 712,
#  'bill': 713,
#  'took': 714,
#  'overall': 715,
#  'viewers': 716,
#  'thinking': 717,
#  'enjoyable': 718,
#  'huge': 719,
#  'ones': 720,
#  'wedding': 721,
#  'max': 722,
#  'break': 723,
#  'favorite': 724,
#  'richard': 725,
#  'liked': 726,
#  'neither': 727,
#  'simon': 728,
#  'cop': 729,
#  'nick': 730,
#  'follow': 731,
#  'opens': 732,
#  'godzilla': 733,
#  'understand': 734,
#  'truman': 735,
#  'immediately': 736,
#  'follows': 737,
#  'scott': 738,
#  'points': 739,
#  'silly': 740,
#  'effect': 741,
#  'country': 742,
#  'slightly': 743,
#  'political': 744,
#  'motion': 745,
#  'merely': 746,
#  'happened': 747,
#  'trouble': 748,
#  'particular': 749,
#  'park': 750,
#  'appear': 751,
#  'musical': 752,
#  'studio': 753,
#  'otherwise': 754,
#  'stone': 755,
#  'bruce': 756,
#  'exciting': 757,
#  'perfectly': 758,
#  'society': 759,
#  'likely': 760,
#  'ultimately': 761,
#  'filled': 762,
#  'brought': 763,
#  'frank': 764,
#  'slow': 765,
#  'members': 766,
#  'inside': 767,
#  'credit': 768,
#  'mess': 769,
#  'ten': 770,
#  'today': 771,
#  'wanted': 772,
#  'eye': 773,
#  'various': 774,
#  'keeps': 775,
#  'truth': 776,
#  'effort': 777,
#  'steve': 778,
#  'woody': 779,
#  'spent': 780,
#  'showing': 781,
#  'spend': 782,
#  'island': 783,
#  'offers': 784,
#  'terrible': 785,
#  'moves': 786,
#  '4': 787,
#  'suddenly': 788,
#  'purpose': 789,
#  'chan': 790,
#  'escape': 791,
#  'party': 792,
#  'english': 793,
#  'air': 794,
#  'ask': 795,
#  'beauty': 796,
#  'fast': 797,
#  'open': 798,
#  'married': 799,
#  'soundtrack': 800,
#  'tim': 801,
#  'cold': 802,
#  'r': 803,
#  'sister': 804,
#  'setting': 805,
#  'fan': 806,
#  'army': 807,
#  'biggest': 808,
#  'wait': 809,
#  'complex': 810,
#  'typical': 811,
#  'government': 812,
#  'memorable': 813,
#  'tarantino': 814,
#  '10': 815,
#  'chase': 816,
#  'fear': 817,
#  'willis': 818,
#  'subplot': 819,
#  'private': 820,
#  'background': 821,
#  'thinks': 822,
#  'killing': 823,
#  'law': 824,
#  'female': 825,
#  'ideas': 826,
#  'lots': 827,
#  'etc': 828,
#  'element': 829,
#  'greatest': 830,
#  'atmosphere': 831,
#  'gun': 832,
#  'sit': 833,
#  'amount': 834,
#  'stand': 835,
#  'indeed': 836,
#  'dull': 837,
#  'tension': 838,
#  'rating': 839,
#  'cinematography': 840,
#  'depth': 841,
#  'box': 842,
#  'west': 843,
#  'gave': 844,
#  'expected': 845,
#  'violent': 846,
#  'steven': 847,
#  'state': 848,
#  'drug': 849,
#  'constantly': 850,
#  'queen': 851,
#  'impact': 852,
#  'mary': 853,
#  'jackson': 854,
#  'dreams': 855,
#  'control': 856,
#  'entirely': 857,
#  'ridiculous': 858,
#  'awful': 859,
#  'theme': 860,
#  'hear': 861,
#  'hold': 862,
#  'leader': 863,
#  'event': 864,
#  'focus': 865,
#  'situations': 866,
#  'view': 867,
#  'longer': 868,
#  'talented': 869,
#  'screenwriter': 870,
#  'club': 871,
#  'seven': 872,
#  'modern': 873,
#  'brown': 874,
#  'mike': 875,
#  'images': 876,
#  'common': 877,
#  'clearly': 878,
#  'eddie': 879,
#  'carry': 880,
#  'budget': 881,
#  'whatever': 882,
#  'sounds': 883,
#  'imagine': 884,
#  'hands': 885,
#  'fairly': 886,
#  'plenty': 887,
#  'intelligence': 888,
#  'vampire': 889,
#  'ride': 890,
#  'cheap': 891,
#  'carrey': 892,
#  'joke': 893,
#  'aspect': 894,
#  'free': 895,
#  'amusing': 896,
#  'subtle': 897,
#  'doctor': 898,
#  'totally': 899,
#  'incredibly': 900,
#  'l': 901,
#  'earlier': 902,
#  'waste': 903,
#  'wish': 904,
#  'sweet': 905,
#  'choice': 906,
#  'disaster': 907,
#  'tone': 908,
#  'sent': 909,
#  'central': 910,
#  'flat': 911,
#  'brief': 912,
#  'reasons': 913,
#  'ability': 914,
#  'delivers': 915,
#  'list': 916,
#  'british': 917,
#  'conclusion': 918,
#  'band': 919,
#  'convincing': 920,
#  'terrific': 921,
#  'recently': 922,
#  'somewhere': 923,
#  'e': 924,
#  'quick': 925,
#  'member': 926,
#  'okay': 927,
#  'elizabeth': 928,
#  'animation': 929,
#  'outside': 930,
#  'u': 931,
#  'casting': 932,
#  'sight': 933,
#  'approach': 934,
#  'pulp': 935,
#  'key': 936,
#  'harry': 937,
#  'lies': 938,
#  'julia': 939,
#  'wrote': 940,
#  'highly': 941,
#  'titanic': 942,
#  'ii': 943,
#  'appearance': 944,
#  'cinematic': 945,
#  'becoming': 946,
#  'thanks': 947,
#  'hate': 948,
#  'opportunity': 949,
#  'believable': 950,
#  'interested': 951,
#  'lucas': 952,
#  'provides': 953,
#  'monster': 954,
#  'telling': 955,
#  'train': 956,
#  'energy': 957,
#  'president': 958,
#  'minor': 959,
#  'cage': 960,
#  'billy': 961,
#  'baby': 962,
#  'allen': 963,
#  'powers': 964,
#  'forget': 965,
#  'thus': 966,
#  'sees': 967,
#  'front': 968,
#  'climax': 969,
#  'cute': 970,
#  'meanwhile': 971,
#  'class': 972,
#  'trailer': 973,
#  'bond': 974,
#  'directing': 975,
#  'actual': 976,
#  'danny': 977,
#  'humans': 978,
#  'jerry': 979,
#  'stands': 980,
#  'shown': 981,
#  'proves': 982,
#  'write': 983,
#  'charm': 984,
#  'discovers': 985,
#  'leading': 986,
#  'partner': 987,
#  'singer': 988,
#  'chemistry': 989,
#  'considering': 990,
#  'grace': 991,
#  'song': 992,
#  'scifi': 993,
#  'puts': 994,
#  'sean': 995,
#  'menace': 996,
#  'college': 997,
#  'j': 998,
#  'produced': 999,
#  'officer': 1000,
#  ...}

# %%
text = """
moviemaking is a lot like being the general manager of an nfl team in the post-salary cap era -- you've got to know how to allocate your resources . 
every dollar spent on a free-agent defensive tackle is one less dollar than you can spend on linebackers or safeties or centers . 
in the nfl , this leads to teams like the detroit lions , who boast a superstar running back with a huge contract , but can only field five guys named herb to block for him . 
in the movies , you end up with films like " spawn " , with a huge special-effects budget but not enough money to hire any recognizable actors . 
jackie chan is the barry sanders of moviemaking . 
he spins and darts across the screen like sanders cutting back through the defensive line . 
watching jackie in operation condor as he drives his motorcycle through the crowded streets of madrid , fleeing an armada of pursuers in identical black compact cars , is reminiscent of sanders running for daylight with the chicago bears in hot pursuit , except that sanders doesn't have to worry about rescuing runaway baby carriages . 
but like the lions star , jackie doesn't have anybody to block for him . 
almost every cent that's invested in a jackie chan movie goes for stunts , and as chan does his own stunts , the rest of the money goes to pay his hospital bills . 
this leaves about 75 cents to pay for things like directors ( chan directs ) , scripts and dubbing and supporting characters , not to mention the hideous title sequence . 
this also explains why the movie was shot in odd places like morocco and spain . 
 ( chan's first release in this country , " rumble in the bronx " , was supposedly set in new york , but was filmed in vancouver , and in the chase scenes the canadian rockies are clearly visible . ) 
heck , jackie doesn't even have enough money for a haircut , looks like , much less a personal hairstylist . 
in condor , chan plays the same character he's always played , himself , a mixture of bruce lee and tim allen , a master of both kung-fu and slapstick-fu . 
jackie is sent by the un to retrieve a cache of lost nazi gold in the north african desert , and is chased by a horde of neo-nazi sympathizers and two stereotypical arabs ( one of the things i like about jackie chan movies : no political correctness ) . 
he is joined by three women , who have little to do except scream , " jackie , save us ! " , and misuse firearms . 
the villain is an old nazi whose legs were broken in the secret base so that he has to be carried everywhere , and he's more pathetic than evil . 
en route , we have an extended motorcycle chase scene , a hilarious fight in the moroccan version of motel 6 with the neo-nazis , and two confrontations with savage natives . 
once at the secret desert base , there is a long chop-socky sequence , followed by the film's centerpiece , a wind-tunnel fight that's even better than the one in face/off . 
this is where the money was spent , on well-choreographed kung-fu sequences , on giant kevlar hamster balls , on smashed-up crates of bananas , and on scorpions . 
ignore the gaping holes in the plot ( how , exactly , if the villain's legs were broken , did he escape from the secret nazi base , and why didn't he take the key with him ? ) . 
don't worry about the production values , or what , exactly , the japanese girl was doing hitchhiking across the sahara . 
just go see the movie . 
operation condor has pretentions of being a " raiders of the lost ark " knockoff , but one wonders what jackie could do with the raiders franchise blocking for him -- with a lawrence kazdan screenplay , a john williams score , spielberg directing and george lucas producing , condor might be an a+ movie . 
however , you've got to go with what you've got , and what you've got in jackie chan is something special -- a talent that mainstream hollywood should , could , and ought to utilize .
"""

# %%
tokens = word_tokenize(text)
translator = str.maketrans('', '', punctuation)
tokens = [w.translate(translator) for w in tokens]
tokens = [w for w in tokens if not w in stop_words]
text = ' '.join(tokens)

# %%
text
# Out:
# 'moviemaking lot like general manager nfl team postsalary cap era  got know allocate resources  every dollar spent freeagent defensive tackle one less dollar spend linebackers safeties centers  nfl  leads teams like detroit lions  boast superstar running back huge contract  field five guys named herb block  movies  end films like  spawn   huge specialeffects budget enough money hire recognizable actors  jackie chan barry sanders moviemaking  spins darts across screen like sanders cutting back defensive line  watching jackie operation condor drives motorcycle crowded streets madrid  fleeing armada pursuers identical black compact cars  reminiscent sanders running daylight chicago bears hot pursuit  except sanders nt worry rescuing runaway baby carriages  like lions star  jackie nt anybody block  almost every cent invested jackie chan movie goes stunts  chan stunts  rest money goes pay hospital bills  leaves 75 cents pay things like directors  chan directs   scripts dubbing supporting characters  mention hideous title sequence  also explains movie shot odd places like morocco spain   chan first release country   rumble bronx   supposedly set new york  filmed vancouver  chase scenes canadian rockies clearly visible   heck  jackie nt even enough money haircut  looks like  much less personal hairstylist  condor  chan plays character always played   mixture bruce lee tim allen  master kungfu slapstickfu  jackie sent un retrieve cache lost nazi gold north african desert  chased horde neonazi sympathizers two stereotypical arabs  one things like jackie chan movies  political correctness   joined three women  little except scream   jackie  save us    misuse firearms  villain old nazi whose legs broken secret base carried everywhere  pathetic evil  en route  extended motorcycle chase scene  hilarious fight moroccan version motel 6 neonazis  two confrontations savage natives  secret desert base  long chopsocky sequence  followed film centerpiece  windtunnel fight even better one faceoff  money spent  wellchoreographed kungfu sequences  giant kevlar hamster balls  smashedup crates bananas  scorpions  ignore gaping holes plot   exactly  villain legs broken  escape secret nazi base  nt take key    nt worry production values   exactly  japanese girl hitchhiking across sahara  go see movie  operation condor pretentions  raiders lost ark  knockoff  one wonders jackie could raiders franchise blocking  lawrence kazdan screenplay  john williams score  spielberg directing george lucas producing  condor might movie  however  got go got  got jackie chan something special  talent mainstream hollywood  could  ought utilize '

# %%
text = tokenizer.texts_to_sequences([text])[0]
text
# Out:
# [5349,
#  108,
#  5,
#  578,
#  3161,
#  20215,
#  334,
#  8203,
#  1659,
#  171,
#  36,
#  6237,
#  57,
#  2938,
#  780,
#  20330,
#  8759,
#  4,
#  179,
#  2938,
#  782,
#  3376,
#  20215,
#  456,
#  6178,
#  5,
#  4323,
#  7542,
#  7107,
#  7184,
#  312,
#  52,
#  719,
#  5969,
#  1532,
#  428,
#  363,
#  271,
#  3515,
#  38,
#  47,
#  24,
#  5,
#  1279,
#  719,
#  39696,
#  881,
#  59,
#  170,
#  4102,
#  5981,
#  105,
#  373,
#  790,
#  1878,
#  18535,
#  5349,
#  11201,
#  33922,
#  479,
#  127,
#  5,
#  18535,
#  2769,
#  52,
#  20330,
#  227,
#  176,
#  373,
#  2827,
#  8292,
#  2250,
#  7514,
#  11095,
#  1818,
#  5921,
#  21982,
#  10686,
#  7091,
#  173,
#  13446,
#  2213,
#  1953,
#  18535,
#  312,
#  4805,
#  2028,
#  4888,
#  1327,
#  4326,
#  558,
#  18535,
#  2,
#  3488,
#  13278,
#  7436,
#  962,
#  5,
#  7542,
#  110,
#  373,
#  2,
#  2488,
#  3515,
#  85,
#  57,
#  6596,
#  373,
#  790,
#  3,
#  112,
#  2030,
#  790,
#  2030,
#  204,
#  170,
#  112,
#  701,
#  1575,
#  8173,
#  660,
#  15000,
#  12162,
#  701,
#  77,
#  5,
#  1129,
#  790,
#  3471,
#  3468,
#  8257,
#  378,
#  15,
#  1060,
#  4629,
#  353,
#  266,
#  12,
#  1914,
#  3,
#  292,
#  1197,
#  1251,
#  5,
#  14671,
#  5971,
#  790,
#  17,
#  538,
#  742,
#  3692,
#  6559,
#  1657,
#  155,
#  34,
#  409,
#  1298,
#  12032,
#  816,
#  37,
#  5427,
#  19837,
#  878,
#  8762,
#  3448,
#  373,
#  2,
#  6,
#  59,
#  170,
#  10458,
#  193,
#  5,
#  11,
#  179,
#  626,
#  25158,
#  8292,
#  790,
#  98,
#  13,
#  140,
#  86,
#  6709,
#  756,
#  354,
#  801,
#  963,
#  1068,
#  8317,
#  373,
#  909,
#  8823,
#  4552,
#  11440,
#  210,
#  4544,
#  1690,
#  2820,
#  4381,
#  2561,
#  4067,
#  30726,
#  17491,
#  16,
#  2869,
#  4,
#  77,
#  5,
#  373,
#  790,
#  38,
#  744,
#  11894,
#  4526,
#  115,
#  399,
#  27,
#  558,
#  390,
#  373,
#  357,
#  43,
#  25258,
#  10215,
#  678,
#  100,
#  4544,
#  206,
#  2635,
#  1812,
#  609,
#  2730,
#  2849,
#  2663,
#  1235,
#  191,
#  10118,
#  3995,
#  2388,
#  7514,
#  816,
#  32,
#  548,
#  331,
#  32150,
#  329,
#  6914,
#  2523,
#  26973,
#  16,
#  9669,
#  3882,
#  7005,
#  609,
#  2561,
#  2730,
#  95,
#  23249,
#  266,
#  2038,
#  1,
#  10748,
#  331,
#  6,
#  58,
#  4,
#  4796,
#  170,
#  780,
#  15732,
#  8317,
#  340,
#  592,
#  20843,
#  4962,
#  26524,
#  8843,
#  4057,
#  7990,
#  1821,
#  25,
#  338,
#  678,
#  2635,
#  1812,
#  791,
#  609,
#  4544,
#  2730,
#  2,
#  66,
#  936,
#  2,
#  3488,
#  327,
#  2109,
#  338,
#  2029,
#  220,
#  21473,
#  479,
#  10449,
#  46,
#  18,
#  3,
#  2827,
#  8292,
#  39853,
#  7058,
#  210,
#  5916,
#  8386,
#  4,
#  2327,
#  373,
#  21,
#  7058,
#  2877,
#  25790,
#  1903,
#  349,
#  76,
#  509,
#  557,
#  1397,
#  975,
#  554,
#  952,
#  4126,
#  8292,
#  126,
#  3,
#  56,
#  171,
#  46,
#  171,
#  171,
#  373,
#  790,
#  45,
#  135,
#  490,
#  2559,
#  146,
#  21,
#  5951,
#  9843]

# %%
text = pad_sequences([text], maxlen=max_len, padding='post')
text
# Out:
# array([[5349,  108,    5, ...,    0,    0,    0]])

# %%
model.predict(text)
# Out:
# 1/1 [==============================] - 0s 173ms/step
# array([[0.10103967]], dtype=float32)

# %%
pred = model.predict(text)
if float(pred) > 0.5:
    print('Positive')
else:
    print('Negative')
# Out:
# 1/1 [==============================] - 0s 19ms/step
# Negative
# C:\Users\Elnaz Parsaei\AppData\Local\Temp\ipykernel_304664\1560334435.py:2: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   if float(pred) > 0.5:
